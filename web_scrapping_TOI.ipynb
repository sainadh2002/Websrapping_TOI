# %%
#Importing Libraries
import numpy as np
import pandas as pd
import bs4
import requests

# %%
#Fetching the Web Page
url = "https://timesofindia.indiatimes.com/"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
#Parsing the HTML
from bs4 import BeautifulSoup
data = BeautifulSoup(response.text ,"lxml")
data
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en"><head><link href="//static.toiimg.com" rel="preconnect"/><link href="//securepubads.g.doubleclick.net" rel="preconnect"/><link href="//pagead2.googlesyndication.com" rel="preconnect"/><link href="//ads.pubmatic.com" rel="preconnect"/><link crossorigin="anonymous" href="//assets.toiimg.com" rel="preconnect"/><link as="script" fetchpriority="high" href="https://assets.toiimg.com/js/til_prebid.js?v=16" rel="preload"/><link as="script" fetchpriority="high" href="https://c.amazon-adsystem.com/aax2/apstag.js" rel="preload"/><link as="script" fetchpriority="high" href="https://securepubads.g.doubleclick.net/tag/js/gpt.js?network-code=7176" rel="preload"/><link as="script" fetchpriority="high" href="https://timesofindia.indiatimes.com/toiads_prebid/minify-1.cms" rel="preload"/><link as="style" href="https://assets.toiimg.com/assets/11024.60ac2bc2.chunk.css" rel="preload" type="text/css"/><link as="style" href="https://assets.toiimg.com/assets/13400.00098eb8.chunk.css" rel="preload" type="text/css"/><link as="style" href="https://assets.toiimg.com/assets/19451.04fb67bb.chunk.css" rel="preload" type="text/css"/><link as="style" href="https://assets.toiimg.com/assets/73971.a9476bbb.chunk.css" rel="preload" type="text/css"/><link as="style" href="https://assets.toiimg.com/assets/ushomedesktop.4d51d22c.chunk.css" rel="preload" type="text/css"/><meta charset="utf-8"/><meta content="ie=edge" http-equiv="x-ua-compatible"/><meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/><title>US News: US News, Top News in India, US election news, Business news, Sports &amp; International News | Times of India</title><meta content="Read Top News in India and around the World on Times of India. Breaking news coverage and analysis on US presidential election, politics, current affairs, business &amp; sports." name="description"/><meta content="News, US News, US election news, India news, English news, international news, business news, US news today, current affairs, breaking news" name="keywords"/><link href="https://timesofindia.indiatimes.com/us" rel="canonical"/><link href="https://timesofindia.indiatimes.com/us" hreflang="en-us" rel="alternate"/><link href="https://timesofindia.indiatimes.com/us" hreflang="en-IN" rel="alternate"/><link href="https://timesofindia.indiatimes.com/us" hreflang="x-default" rel="alternate"/><link href="android-app://com.toi.reader.activities/toi.index.deeplink/HomeL1/Top-01" rel="alternate"/><link href="https://timesofindia.indiatimes.com/us/amp" rel="amphtml"/><meta content="US News: US News, Top News in India, US election news, Business news, Sports &amp; International News | Times of India" property="og:title"/><meta content="https://timesofindia.indiatimes.com/us" property="og:url"/><meta content="https://static.toiimg.com/photo/47529300.cms" property="og:image"/><meta content="Read Top News in India and around the World on Times of India. Breaking news coverage and analysis on US presidential election, politics, current affairs, business &amp; sports." property="og:description"/><meta content="https://timesofindia.indiatimes.com/us" property="twitter:url"/><meta content="https://static.toiimg.com/photo/47529300.cms" property="twitter:image"/><meta content="US News: US News, Top News in India, US election news, Business news, Sports &amp; International News | Times of India" property="twitter:title"/><meta content="Read Top News in India and around the World on Times of India. Breaking news coverage and analysis on US presidential election, politics, current affairs, business &amp; sports." property="twitter:description"/><meta name="twitter:card" value="summary_large_image"/><meta name="twitter:site" value="@timesofindia"/><meta content="1070" property="og:image:width"/><meta content="580" property="og:image:height"/><meta content="yes" name="mobile-web-app-capable"/><meta content="en" http-equiv="content-language"/><meta content="text/html; charset=utf-8" h ...
#   function stpPgtn(event) {
#     event.stopPropagation();
#   }
#   function stpPgtnAndPrvntDefault(event) {
#     event.stopPropagation();
#     event.preventDefault();
#
#   }
#   window.isPrime=false; window.showAdsOnTOIPlus=false; window.isPrimeLayout=false;  window.isCWVTrackingAlreadyManged= false;
#     window.cwvReportingInfo = window.cwvReportingInfo || {}
#     window.cwvReportingInfo.userPercentage = "undefined";
#     window.cwvReportingInfo.section = "undefined";
#     window.cwvReportingInfo.dataStore = "undefined";
#     window.cwvReportingInfo.subsection = "undefined";
#     window.cwvReportingInfo.business_property = "undefined";
#     window.cwvReportingInfo.browsing_platform = "undefined";
#     window.cwvReportingInfo.page_template = "undefined";
#   </script><script>window.gptRan = false;
#   window.PWT = window.PWT || {};
#   window.googletag = window.googletag || { cmd: [] };
#   window.TimesApps =  window.TimesApps || {};
#   window.TimesApps.PopUpV2Manager = window.TimesApps.PopUpV2Manager || { cmd: []}
#   window.debugLogs = window.debugLogs || function (logStr, val) {
#     try {
#       if (
#         typeof window === 'object' &&
#         window.location.href.indexOf('debugLogs=1') > -1
#       ) {
#         console.log(logStr, val);
#       }
#     } catch (e) {
#       //console.log(e);
#     }
#   };
#   window.getFromClient = window.getFromClient || function (url, cb) {
#       var xhr = new XMLHttpRequest();
#       xhr.open("GET", url, true);
#       xhr.onreadystatechange = function () {
#           if (this.readyState == 4 && this.status == 200) {
#               if (cb && typeof cb === 'function') {
#                 try {
#                   var data = JSON.parse(this.responseText);
#                   cb(data);
#                 } catch (e) {
#                   cb(this.responseText);
#                 }
#               }
#           }
#       }
#       xhr.send();
#   }</script><script>window.Times = window.Times || {};
#   window.Times.pageLoadAdsArr = [{"name":"topBand","adCode":"\u002F7176\u002FTOI\u002FTOI_ROS_TOP_Strip_1000x60","tn":"ad","adType":"dfp","divId":"div-gpt-ad-topband-1628142867492-0","size":[[1000,60]],"checkJarvisIsAdActive":"topBand","addclass":"isAdActive","deviceType":"","prebid":false},{"name":"masthead","adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_ATF_728","divId":"div-gpt-ad-1416989701201-55289562-b26c-4b5f-846e-074089ea4c6d-atf","size":[[980,200],[970,250],[728,90],[750,200],[930,180],[950,90],[980,120],[970,90]],"prebid":false,"adType":"dfp","tn":"ad","deviceType":""},{"jname":"earPlugAdsLeft","deviceType":"","divId":5026514343,"prebid":false},{"jname":"earPlugAdsRight","deviceType":"","divId":9258006336,"prebid":false},{"tn":"ad","adType":"dfp","size":[[300,250]],"adCode":"\u002F7176\u002FTOI\u002FTOI_Home\u002FTOI_Home_Home_New\u002FTOI_HP_NW_ATF_300","slotId":"hp-21517220297485","resolution":{"res1000px":{"tn":"ad","adType":"dfp","size":[[300,250]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_ATF_300","slotId":"hp1-15172202974res1000px"},"res1160px":{"tn":"ad","adType":"dfp","size":[[300,250]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_ATF_300","slotId":"hp-1517220297res1160px"}},"divId":"hp-21517220297485","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[[728,90],[970,90]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_MTF_728","slotId":"se1-1517220297481","divId":"se1-1517220297481","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[[728,90],[970,90]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_MTF1_728","slotId":"sec2-21517220297482","divId":"sec2-21517220297482","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[300,250],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_MTF_300","slotId":"city-1517220297486","divId":"city-1517220297486","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[300,250],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_BTF_300","slotId":"us-1517220297467","divId":"us-1517220297467","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[300,250],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_BTF2_300","slotId":"nri-1517220297467","divId":"nri-1517220297467","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[[728,90],[970,90]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_BTF1_728","slotId":"sec4-1517220297484","divId":"sec4-1517220297484","deviceType":"","prebid":false},{"adType":"dfp","adName":"gutter","fallback":{"lhs":{"adName":"fallback","tn":"ad","size":[[120,600],[125,600]],"adType":"dfp","adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_Home_Home_US_New\u002FTOI_HP_US_NW_LHS_125","divId":"d7912bb2-44be-4fbd-8ca7-09b5d7398213"},"rhs":{"adName":"fallback","tn":"ad","size":[[125,600],[120,600]],"adType":"dfp","adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_Home_Home_US_New\u002FTOI_HP_US_NW_RHS_125","divId":"6a4bb6db-1aa2-4182-810b-ebac1f7ee743"}},"tn":"ad","adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_OP_Innov1","divId":"9fe85d9b-65aa-4ae4-987f-bae28ec7bb84","name":"gutter","failover":[{"adCode":"\u002F7176\u002FTOI\u002FTOI_ROS\u002FTOI_ROS_Skinner_LHS_125","size":[[125,600],[160,600],[120,600]],"divId":"TOI_appgutter_left","perpetualRefresh":1},{"adCode":"\u002F7176\u002FTOI\u002FTOI_ROS\u002FTOI_ROS_Skinner_RHS_125","size":[[125,600],[160,600],[120,600]],"divId":"TOI_appgutter_right","perpetualRefresh":1}],"perpetualRefresh":1,"deviceType":"","prebid":false}];</script><script>window.Times = window.Times || {};
#         window.Times.adsKeys = window.Times.adsKeys || {};
#         window.Times.adsKeys = {"Meta_Keywords":"News, US News, US election news, India news, English news, international news, business news, US news today, current affairs, breaking news","Content_URL":"https:\u002F\u002Ftimesofindia.indiatimes.com\u002Fus","Tmpl_SCN":"home_us","Channel":"toi","SCN":"us"};</script><script async="">function loadScript(url) {
#             var script = document.createElement('script');
#             script.src = url;
#             script.async = true;
#             script.onerror = function() {
#               try{ window.DisplayBlkrDetected('prebidBlocked') }
#               catch(e){ window.prebidBlocked = true; }
#             };
#             document.head.appendChild(script);
#           }
#           loadScript('https://assets.toiimg.com/js/til_prebid.js?v=16')</script><script>
#       function loadTAM(){
#           !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","https://c.amazon-adsystem.com/aax2/apstag.js");
#           // initialize apstag with global settings
#           apstag.init({"pubID":"5025","adServer":"googletag"});
#       }
#       loadTAM();</script><script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js?network-code=7176"></script><script async="" src="https://timesofindia.indiatimes.com/toiads_prebid/minify-1.cms"></script><script>window.App={"apiUrl":"","state":{"adCaller":{"prebidFlag":true,"prebidCountryList":[],"adsQueueData":[{"name":"topBand","adCode":"\u002F7176\u002FTOI\u002FTOI_ROS_TOP_Strip_1000x60","tn":"ad","adType":"dfp","divId":"div-gpt-ad-topband-1628142867492-0","size":[[1000,60]],"checkJarvisIsAdActive":"topBand","addclass":"isAdActive","deviceType":"","prebid":false},{"name":"masthead","adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_ATF_728","divId":"div-gpt-ad-1416989701201-55289562-b26c-4b5f-846e-074089ea4c6d-atf","size":[[980,200],[970,250],[728,90],[750,200],[930,180],[950,90],[980,120],[970,90]],"prebid":false,"adType":"dfp","tn":"ad","deviceType":""},{"jname":"earPlugAdsLeft","deviceType":"","divId":5026514343,"prebid":false},{"jname":"earPlugAdsRight","deviceType":"","divId":9258006336,"prebid":false},{"tn":"ad","adType":"dfp","size":[[300,250]],"adCode":"\u002F7176\u002FTOI\u002FTOI_Home\u002FTOI_Home_Home_New\u002FTOI_HP_NW_ATF_300","slotId":"hp-21517220297485","resolution":{"res1000px":{"tn":"ad","adType":"dfp","size":[[300,250]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_ATF_300","slotId":"hp1-15172202974res1000px"},"res1160px":{"tn":"ad","adType":"dfp","size":[[300,250]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_ATF_300","slotId":"hp-1517220297res1160px"}},"divId":"hp-21517220297485","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[[728,90],[970,90]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_MTF_728","slotId":"se1-1517220297481","divId":"se1-1517220297481","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[[728,90],[970,90]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_MTF1_728","slotId":"sec2-21517220297482","divId":"sec2-21517220297482","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[300,250],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_MTF_300","slotId":"city-1517220297486","divId":"city-1517220297486","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[300,250],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_BTF_300","slotId":"us-1517220297467","divId":"us-1517220297467","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[300,250],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_BTF2_300","slotId":"nri-1517220297467","divId":"nri-1517220297467","deviceType":"","prebid":false},{"tn":"ad","adType":"dfp","size":[[728,90],[970,90]],"adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_BTF1_728","slotId":"sec4-1517220297484","divId":"sec4-1517220297484","deviceType":"","prebid":false},{"adType":"dfp","adName":"gutter","fallback":{"lhs":{"adName":"fallback","tn":"ad","size":[[120,600],[125,600]],"adType":"dfp","adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_Home_Home_US_New\u002FTOI_HP_US_NW_LHS_125","divId":"d7912bb2-44be-4fbd-8ca7-09b5d7398213"},"rhs":{"adName":"fallback","tn":"ad","size":[[125,600],[120,600]],"adType":"dfp","adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_Home_Home_US_New\u002FTOI_HP_US_NW_RHS_125","divId":"6a4bb6db-1aa2-4182-810b-ebac1f7ee743"}},"tn":"ad","adCode":"\u002F7176\u002FTOI_US\u002FTOI_Home_US\u002FTOI_HOME_HOME_US_2\u002FTOI_HP_US_2_OP_Innov1","divId":"9fe85d9b-65aa-4ae4-987f-bae28ec7bb84","name":"gutter","failover":[{"adCode":"\u002F7176\u002FTOI\u002FTOI_ROS\u002FTOI_ROS_Skinner_LHS_125","size":[[125,600],[160,600],[120,600]],"divId":"TOI_appgutter_left","perpetualRefresh" ...
#   setTimeout(function() {
#     w[l]=w[l]||[];
#     w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#     var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.crossOrigin='anonymous';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   },0);
# })(window,document,'script','dataLayer','GTM-P3PMSJN');
# window.dataLayer = window.dataLayer || [];
# </script><script>var _comscore = _comscore || [];
#           var objComScore = { c1: "2", c2: "6036484" };
#           window.TimesApps = window.TimesApps || {};
#           function loadComscore() {
#             var s = document.createElement("script"),
#               el = document.getElementsByTagName("script")[0];
#             s.async = true;
#             s.defer = true;
#             s.src =
#               (document.location.protocol == "https:" ? "https://sb" : "http://b") +
#               ".scorecardresearch.com/beacon.js";
#             el.parentNode.insertBefore(s, el);
#           };
#
#           function fireComscore() {
#             if (typeof(COMSCORE) !== "undefined" && typeof(COMSCORE.beacon) === "function") {
#               COMSCORE.beacon(objComScore);
#             }
#           }
#
#           if (window.TimesGDPR && TimesGDPR.common.consentModule.gdprCallback) {
#             TimesGDPR.common.consentModule.gdprCallback(function(dataObj) {
#               if (dataObj.isEUuser) {
#                 objComScore["cs_ucfr"] = 0;
#               }
#               _comscore.push(objComScore);
#               loadComscore();
#               window.TimesApps.fireComscore = fireComscore;
#             });
#           } else{
#             objComScore["cs_ucfr"] = 0;
#             _comscore.push(objComScore);
#             loadComscore();
#           }</script><script type="text/javascript">
# try {
#     var setCMPCookie = function(name, value, domainName, days){
#         if(!!domainName){
#             var domain = ";domain="+domainName;
#         }
#         if(!!days){
#             //Below variable is one day time in mili seconds.
#             var _oneDayinMS = 24*60*60*1000;
#             var d = new Date();
#             d.setTime(d.getTime() + (days*_oneDayinMS));
#             var expires = ";expires="+d.toUTCString();
#         }
#         document.cookie = name+"=" +value + ( ( expires ) ? expires : '' ) + ( ( domain ) ? domain : '' ) + ";path=/";
#     };
#
#     var optOutCookieName = "optout";
#     var optOutCookieAge = 365;
#     var dateOneTrust = new Date();
#     var urlParamsCmp = new URLSearchParams(window.location.search);
#
#     dateOneTrust.setTime(dateOneTrust.getTime() + (optOutCookieAge * 24 * 60 * 60 * 1000));
#
#
#     function setOnAcceptOptOut() {
#         setCMPCookie(optOutCookieName, '0' , window.location.host ,optOutCookieAge);
#         setCMPCookie('ckns_policyV2', '1', window.location.host, 365);
#         if (window.localStorage) {
#             window.localStorage.setItem('ccpaGdprPopupShown', '1');
#         }
#     }
#
#     function setOnRejectOptOut() {
#         setCMPCookie(optOutCookieName, '1' , window.location.host ,optOutCookieAge);
#         setCMPCookie('ckns_policyV2', null , window.location.host, 365);
#         if (window.localStorage) {
#             window.localStorage.setItem('ccpaGdprPopupShown', '1');
#         }
#     }
#
#     // Make sure that the properties exist on the window.
#     window.googlefc = window.googlefc || {};
#     window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#     window.googlefc.ccpa = window.googlefc.ccpa || {}
#
#     // Function to check if gpt.js is already loaded
#     function isGPTScriptLoaded() {
#         return Array.from(document.getElementsByTagName('script'))
#             .some(script => script.src && script.src.includes('gpt.js'));
#     }
#
#     // Function to dynamically load the gpt.js script
#     function loadGPTScript() {
#         if (!isGPTScriptLoaded()) {
#             var script = document.createElement('script');
#             script.src = 'https://securepubads.g.doubleclick.net/tag/js/gpt.js?network-code=7176'; // Replace with actual URL of gpt.js
#             script.async = true;
#             script.onload = function() {
#                 attachGoogleCMPListners();
#             };
#             script.onerror = function() {
#                 console.log('Failed to load gpt.js script');
#             };
#             document.head.appendChild(script);
#         } else {
#             attachGoogleCMPListners();
#         }
#     }
#
#     function attachGoogleCMPListners() {
#         window.googlefc.callbackQueue.push({
#             'CONSENT_DATA_READY':
#             () => __tcfapi('addEventListener', 2.2, (consentData, success) => {
#                 // 1. Check if GDPR applies
#                 if (consentData.gdprApplies === true) {
#                     // 2. Check if the consent process was completed successfully
#                     if (consentData.eventStatus === 'useractioncomplete' || consentData.eventStatus === 'tcloaded') {
#                         // 3. Check if the user has consented to personalized ads (Purpose 1)
#                         if (consentData.purpose && consentData.purpose.consents && consentData.purpose.consents["3"] === true) {
#                             // User has consented to personalized ads, unset the opt out cookie
#                             setOnAcceptOptOut();
#                         } else {
#                             // User did not consent to personalized ads, set the opt out cookie
#                             setOnRejectOptOut();
#                         }
#                     } else {
#                         // Consent process was not completed
#                         setOnRejectOptOut();
#                     }
#
#                 } else {
#                     // GDPR doesn't apply, proceed with standard behavior or do not require consent
#                     setOnAcceptOptOut();
#                 }
#             })
#         });
#
#         // Queue the callback on the callbackQueue.
#         window.googlefc.callbackQueue.push({
#             'INITIAL_CCPA_DATA_READY':
#             () => {
#             switch (googlefc.ccpa.getInitialCcpaStatus()) {
#                 case googlefc.ccpa.InitialCcpaStatusEnum.CCPA_DOES_NOT_APPLY:
#                 setOnAcceptOptOut();
#                 break;
#                 case googlefc.ccpa.InitialCcpaStatusEnum.NOT_OPTED_OUT:
#                 setOnRejectOptOut();
#                 break;
#                 case googlefc.ccpa.InitialCcpaStatusEnum.OPTED_OUT:
#                 setOnAcceptOptOut();
#                 break;
#             }
#             }
#         });
#     }
#
#     // Call the function to ensure the script is loaded
#     loadGPTScript();
# } catch (err) {
#   console.log("cmp_js error", err);
# }</script><script type="text/javascript">window.TimesApps = window.TimesApps || {};
# var TimesApps = window.TimesApps || {};
# TimesApps.popupManagerFullyInitilizedEvent = new CustomEvent('popup_manager_ready', {
#     detail: { message: 'popup_manager_ready' }
# });
# TimesApps.popupManger2 = function popupManagerHigherOrderPopups() {
#     window.TimesApps = window.TimesApps || {};
#     var TimesApps = window.TimesApps || {};
#     const debugLogs = function(str1, str2, str3) {
#       if (
#         typeof window === 'object' &&
#         window.location.search &&
#         window.location.search.indexOf('debug') > -1 &&
#         window.console
#       ) {
#         console.log(str1, str2, str3);
#       }
#     };
#     TimesApps.PopUpList = {};
#     TimesApps.PopupV2 = function(name, showPopCallback , priority, data) {
#       const dataObj = data || {};
#       this.id = name;
#       this.lastShownTimeStamp = dataObj.lastShownTimeStamp
#         ? dataObj.lastShownTimeStamp
#         : null;
#       this.showPopCallback = showPopCallback;
#       this.priority = priority;
#       // this.status;
#       this.userActionStatus = null;
#       this.retryDone = 0;
#       this.shown = 0;
#       // this.forceRepeat = dataObj.forceRepeat;
#     };
#
#     TimesApps.PopupV2.prototype.showPopCallback = function() {
#       return this.showPopCallback();
#     };
#
#     TimesApps.PopupV2.prototype.getDetailsPopUp = function() {
#       return { ...this };
#     };
#
#     TimesApps.PopupV2.prototype.onReadyCallback = function(status) {
#       this.ready = status;
#       if (status === 3) {
#         this.setStatus(false);
#       }
#     };
#
#     TimesApps.PopupV2.prototype.isReady = function() {
#       return this.ready;
#     };
#
#     TimesApps.PopupV2.prototype.onShowCallback = function(status) {
#       this.shown = status;
#     };
#
#     TimesApps.PopupV2.prototype.getStatus = function() {
#       return this.status;
#     };
#
#     TimesApps.PopupV2.prototype.setStatus = function(status) {
#       this.status = status || false;
#     };
#
#     TimesApps.PopupV2.prototype.getLastShownTime = function() {
#       return this.lastShownTimeStamp;
#     };
#
#     TimesApps.PopupV2.prototype.onUserActionCallback = function(status) {
#       this.userActionStatus = status;
#     };
#
#     TimesApps.PopUpV2Manager = (function() {
#       /*
#           1. Register overlay
#           2. Decide overlay priority
#           3. show overlay
#
#
#           Register overlay
#               - registerOverlay
#                   - return onReadyCallback
#                   - all popup's call onReadyCallback to mark status, they are ready to be called
#               - read priority from config
#               - create priority queue
#
#           Decide overlay priority
#               - read priority queue
#               - call if 1st is ready
#                       - if status OK  - call
#                       - else if not needed to be called, call Next
#               -
#
#           Show overlay
#               - save state in Localstorage
#                   - show - true/false
#                   - timestamp
#
#
#           Config
#               - popup list
#               - priority for each
#               - show frequency
#       */
#
#       const config = {
#         browserStorageKey: 'popUpManagerHigherOrderPopUps',
#       };
#
#       const constants = {
#         HRS_IN_DAY: 24,
#         MINS_IN_HR: 60,
#         SEC_IN_MIN: 60,
#         MilliSEC_IN_SEC: 1000,
#       };
#
#       const fn = {
#         _docReady(forcefully = false) {
#           (function() {
#             const referrer = document.referrer;
#             try {
#               if(forcefully) {
#                 const data1 = JSON.parse(
#                   localStorage.getItem(config.browserStorageKey),
#                 );
#                 if (data1.actualData &&
#                   Array.isArray(data1.actualData) &&
#                   data1.actualData.length > 0 &&
#                   (TimesApps.PopUpList[data1.actualData[0].name] &&
#                   TimesApps.PopUpList[data1.actualData[0].name].getDetailsPopUp()?.id === 'interstitial')){
#                     let pageViewsAfterGDPR = parseInt(localStorage.getItem('pageViewsAfterGDPR'), 10);
#                     if (!pageViewsAfterGDPR && isNaN(pageViewsAfterGDPR)) {
#                         pageViewsAfterGDPR = 0;
#                     }
#                     localStorage.setItem('pageViewsAfterGDPR', pageViewsAfterGDPR + data1.burninterval);
#                     return;
#                   }
#               }
#               if (window.localStorage && window.toi_client_side_settings) {
#                   if(window.localStorage && localStorage.getItem("ccpaGdprPopupShown") === '1'){
#                       let pageViewsAfterGDPR = parseInt(localStorage.getItem('pageViewsAfterGDPR'), 10);
#                           if (!pageViewsAfterGDPR && isNaN(pageViewsAfterGDPR)) {
#                               pageViewsAfterGDPR = 0;
#                           }
#                           localStorage.setItem('pageViewsAfterGDPR', pageViewsAfterGDPR + 1);
#                       }
#                 let pageViews =
#                   localStorage.getItem('pageViewsAfterGDPR') &&
#                   parseInt(localStorage.getItem('pageViewsAfterGDPR'), 10);
#                 let data = JSON.parse(
#                   localStorage.getItem(config.browserStorageKey),
#                 );
#                 fn._saveAndMakeReady(data, pageViews);
#                 if (
#                   data &&
#                   Date.now() - data.time >
#                   data.burntime * constants.SEC_IN_MIN * constants.MilliSEC_IN_SEC
#                 ) {
#                   localStorage.removeItem(config.browserStorageKey);
#                   localStorage.setItem('pageViewsAfterGDPR', 1);
#                   pageViews = parseInt(localStorage.getItem('pageViewsAfterGDPR'), 10);
#                   data = null;
#                 }
#                 if (!data) {
#                   window.toi_client_side_settings.time = Date.now();
#                   data = window.toi_client_side_settings;
#                   data.actualData = JSON.parse(JSON.stringify(data.priority));
#                   data.actualData.sort((a, b) => a.priority - b.priority);
#                   if (!(localStorage.getItem("autoCcpaGdprPopupShown"))){
#                     data.nextPageView = 1 + data.burninterval;
#                   } else {
#                     data.nextPageView = 1;
#                   }
#                   fn._saveAndMakeReady(data, pageViews);
#                 }
#                 config.burninterval = data.burninterval;
#                 config.burntime = data.burntime;
#                 config.data = data;
#                 if (config.data.actualData &&
#                   Array.isArray(config.data.actualData) &&
#                   config.data.actualData.length > 0) {
#                   if(config.data.nextPageView - (config.burninterval + 1) === pageViews || forcefully){
#                     if (!forcefully){
#                       document.addEventListener('popup_manager_ready', function(event) {
#                         if (!(TimesApps.PopUpList[config.data.actualData[0].name] && config.data.actualData[0].status === 1)) {
#                           return fn._docReady(true);
#                         }
#                         TimesApps.PopUpList[config.data.actualData[0].name].showPopCallback()
#                       });
#                     } else {
#                       if (!(TimesApps.PopUpList[config.data.actualData[0].name] && config.data.actualData[0].status === 1)) {
#                         return fn._docReady(true);
#                       }
#                       TimesApps.PopUpList[config.data.actualData[0].name].showPopCallback()
#                     }
#                   }
#                 }
#               }
#             } catch(ex){
#               console.log(ex, "Popup manager Error")
#             }
#           })();
#         },
#         _init() {
#           console.log('Pop up manager is initialtized');
#           if(Array.isArray(window.TimesApps.PopUpV2Manager.regiteredPopup) && window.TimesApps.PopUpV2Manager.regiteredPopup.length > 0){
#               window.TimesApps.PopUpV2Manager.regiteredPopup.forEach(function(cbfn){
#                   if(typeof cbfn === 'function'){
#                       cbfn()
#                   }
#               })
#           }
#         },
#         _saveAndMakeReady(data, pageViews) {
#           if(data?.actualData &&
#             Array.isArray(data?.actualData) &&
#             data.actualData.length > 0 && pageViews && pageViews > 0){
#             // eslint-disable-next-line guard-for-in, no-restricted-syntax
#             data.actualData.some((singleData, index) => {
#                 if (singleData.status === 1) {
#                     const shouldRepeat = singleData.forceRepeat || singleData.repeat;
#                     if (shouldRepeat) {
#                         singleData.priority = data.actualData[data.actualData.length - 1].priority + 1;
#                         singleData.status = 0;
#                         data.actualData.push(singleData);
#                     }
#                     data.actualData.shift();
#                 }
#                 if(data.actualData && Array.isArray(data.actualData) && data.actualData.length > 0){
#                   singleData = data.actualData[0];
#                   if (data.nextPageView === pageViews) {
#                       singleData.status = 1;
#                       data.nextPageView = pageViews + data.burninterval + 1;
#                       return true;
#                   }
#                 }
#             });
#             localStorage.setItem(config.browserStorageKey, JSON.stringify(data));
#           }
#         },
#         _registerPopUp(id, callBack) {
#           let callbacks = {};
#           try{
#             const popUp = fn._createPopUpObject(id, callBack);
#             if (!popUp) return null;
#             callbacks = {
#               onReadyCallback: fn._onReadyCallback.bind(popUp),
#               onShowCallback: fn._onShowCallback.bind(popUp),
#               onUserActionCallback: popUp.onUserActionCallback,
#               getDetail: fn._getDetails.bind(popUp),
#             };
#             popUp.callbacks = callbacks;
#             TimesApps.PopUpList[id] = popUp;
#             let data = JSON.parse(
#               localStorage.getItem(config.browserStorageKey),
#             );
#             let actualData = Array.isArray(data.actualData) && data.actualData.length > 0 ? data.actualData.map((d)=> d.name).sort() : [];
#             let popupList = Object.keys(TimesApps.PopUpList).sort();
#             if (actualData.join() === popupList.join()){
#               document.dispatchEvent(TimesApps.popupManagerFullyInitilizedEvent);
#             }
#           } catch (err) {}
#           return callbacks;
#         },
#         _getDetails(){
#             return this.getDetailsPopUp();
#         },
#         _onReadyCallback(status) {
#           this.onReadyCallback(status);
#         },
#         _onShowCallback(status) {
#             /*
#              * popup displayed
#              */
#             debugLogs('*** onShowCallback', this, status);
#             this.onShowCallback(status);
#             fn._setStatusInStorage(this, status);
#           },
#           _setStatusInStorage(obj, status) {
#             const data = fn._getStatusFromStorage();
#             const index = fn._getIndex(data.actualData, obj.id);
#             data.actualData[index].lastShownTimeStamp = Date.now();
#             data.actualData[index].shown = status;
#             data.actualData[index].atPageView = parseInt(
#                 localStorage.getItem('pageViewsAfterGDPR'),
#                 10,
#             )
#             if( data?.actualData && Array.isArray(data?.actualData) && data?.actualData.length){
#               data.actualData.shift();
#               fn._setStatusFromStorage(data);
#             }
#             if (status === false) {
#               fn._docReady(true);
#             }
#           },
#           _getIndex(data, named) {
#             let index = -1;
#             if(data){
#                 Object.keys(data).forEach((key, i) => {
#                     if (data[key].name === named) {
#                         index = i;
#                     }
#                 });
#             }
#             return index;
#           },
#         _createPopUpObject(id, showCallback = null) {
#             const popUpdata = {};
#             const data = fn._getStatusFromStorage();
#             if (!(data && data.actualData)){
#                 return null;
#             }
#             const { priority, lastShownTimeStamp, name } = data.actualData.find(
#               item => item.name === id,
#             ) || {};
#             if (name){
#               popUpdata.lastShownTimeStamp = lastShownTimeStamp;
#               return new TimesApps.PopupV2(name, showCallback, priority, popUpdata);
#             }
#         },
#         _isPopuManagerRunningInSession() {
#           if (localStorage.getItem("pageViewsAfterGDPR") && fn._getStatusFromStorage()) return true;
#           return false;
#         },
#         _setStatusFromStorage(data) {
#             localStorage.setItem(config.browserStorageKey, JSON.stringify(data));
#         },
#         _getStatusFromStorage() {
#           const jsonData = localStorage.getItem(config.browserStorageKey);
#           let data;
#
#           try {
#             data = JSON.parse(jsonData) || {};
#           } catch (e) {
#             data = null;
#             //console.log('popupManager, JSON error');
#           }
#
#           return data;
#         },
#       };
#
#       fn._docReady();
#       const regiteredPopup = window.TimesApps.PopUpV2Manager.cmd || [];
#       setTimeout(()=>{
#         fn._init();
#       },100)
#
#       const api = {
#         cmd: {
#             push: function(callback){
#                 if(typeof callback === 'function'){
#                     callback();
#                 }
#             }
#         },
#         regiteredPopup: regiteredPopup,
#         register(id, showCallback) {
#           return fn._registerPopUp(id, showCallback);
#         },
#         isPopuMangerRunning() {
#           return fn._isPopuManagerRunningInSession();
#         },
#         reloadPopupManager(forcefully) {
#           return fn._docReady(forcefully);
#         },
#       };
#
#       return api;
#     })();
#   }; </script><script type="text/javascript">function ccaudjs() {
#     var toiId = '2658:3';
#     var etimesId = '65615:2608';
#     var etimeschannel = window.Times &&  window.Times.adsKeys &&  window.Times.adsKeys.Channel === 'etimes';
#
#     var clientId = "cid=" + (etimeschannel ? etimesId : toiId) + "&";
#     var dsmi="", _fpc="", _optout="";
#     var cookie = document.cookie.match('(^|;)\s* ' + "_col_ccds" + '\s*=\s*([^;]+)')?.pop() || '';
#     var fpccookie = document.cookie.match('(^|;)\s* ' + "_col_uuid" + '\s*=\s*([^;]+)')?.pop() || '';
#     var optoutcookie = document.cookie.match('(^|;)\s* ' + "optout" + '\s*=\s*([^;]+)')?.pop() || '';
#     if(!!cookie) {
#           dsmi = "dsmi=" + cookie + "&";
#     }
#     if(!!fpccookie) {
#         _fpc = "fpc=" + fpccookie + "&";
#     }
#     if(!!optoutcookie) {
#         _optout = "optout=" + optoutcookie + "&";
#     }
#     var url = "https://ade.clmbtech.com/cde/aef/var=colaud?"+clientId+dsmi+_fpc+_optout+"_u="+encodeURIComponent(window.location.href);
#     var gtmdmp = document.createElement('script');
#     gtmdmp.type = 'text/javascript';
#     gtmdmp.async = true;
#     gtmdmp.defer = true;
#     gtmdmp.src = url;
#     var s = document.getElementsByTagName('head')[0];
#     s.parentNode.insertBefore(gtmdmp, s)
#     setTimeout(function(){dumpAudsToLocalStorage()},5000);
#   }
#   function dumpAudsToLocalStorage() {
#     if(typeof localStorage != "undefined" && typeof colaud != "undefined" && colaud.aud != ""){
#       localStorage.setItem('colaud', colaud.aud);
#     }
#   }
#   setTimeout(function(){ccaudjs()},5000);</script><script>
# var _mfq = window._mfq || [];
# _mfq.push(["setVariable", "toi_titan", window.location.href]);
#
# !(function(f, b, e, v, n, t, s) {
#     function loadFBEvents(isFBCampaignActive) {
#       if (!isFBCampaignActive) {
#         return;
#       }
#       (function(f, b, e, v, n, t, s) {
#         if (f.fbq) return;
#         n = f.fbq = function() {
#           n.callMethod ? n.callMethod(...arguments) : n.queue.push(arguments);
#         };
#         if (!f._fbq) f._fbq = n;
#         n.push = n;
#         n.loaded = !0;
#         n.version = '2.0';
#         n.queue = [];
#         t = b.createElement(e);
#         t.async = !0;
#         t.defer = !0;
#         t.src = v;
#         s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s);
#       })(f, b, e, 'https://connect.facebook.net/en_US/fbevents.js', n, t, s);
#       fbq('init', '593671331875494');
#       fbq('track', 'PageView');
#     };
#
#     function loadGtagEvents(isGoogleCampaignActive) {
#       if (!isGoogleCampaignActive) {
#         return;
#       }
#       var id = document.getElementById('toi-plus-google-campaign');
#       if (id) {
#         return;
#       }
#       (function(f, b, e, v, n, t, s) {
#         t = b.createElement(e);
#         t.async = !0;
#         t.defer = !0;
#         t.src = v;
#         t.id = 'toi-plus-google-campaign';
#         s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s);
#       })(f, b, e, 'https://www.googletagmanager.com/gtag/js?id=AW-877820074', n, t, s);
#     };
#
#     function loadSurvicateJs(allowedSurvicateSections = []){
#       const section =  window.location.pathname.split('/')[1]
#       const isHomePageAllowed = window.location.pathname === '/' && allowedSurvicateSections.includes('homepage')
#
#       if(allowedSurvicateSections.includes(section) || isHomePageAllowed){
#         (function(w) {
#
#          function setAttributes() {
#                     var prime_user_status = window.isPrime ? 'paid' : 'free' ;
#                     w._sva.setVisitorTraits({
#                     toi_user_subscription_status : prime_user_status
#                         });
#                 }
#
#          if (w._sva && w._sva.setVisitorTraits) {
#                     setAttributes();
#                 } else {
#                     w.addEventListener("SurvicateReady", setAttributes);
#           }
#
#           var s = document.createElement('script');
#           s.src = 'https://survey.survicate.com/workspaces/0be6ae9845d14a7c8ff08a7a00bd9b21/web_surveys.js';
#           s.async = true;
#           var e = document.getElementsByTagName('script')[0];
#           e.parentNode.insertBefore(s, e);
#         })(window);
#       }
#
#     }
#
#     window.TimesApps = window.TimesApps || {};
#     var TimesApps = window.TimesApps;
#     TimesApps.toiPlusEvents = function(config) {
#       var isConfigAvailable = "toiplus_site_settings" in f && "isFBCampaignActive" in f.toiplus_site_settings && "isGoogleCampaignActive" in f.toiplus_site_settings;
#       var isPrimeUser = window.isPrime;
#       var isPrimeUserLayout = window.isPrimeUserLayout;
#       if (isConfigAvailable && !isPrimeUser) {
#         loadGtagEvents(f.toiplus_site_settings.isGoogleCampaignActive);
#         loadFBEvents(f.toiplus_site_settings.isFBCampaignActive);
#         loadSurvicateJs(f.toiplus_site_settings.allowedSurvicateSections);
#       } else {
#           var JarvisUrl = 'https://jarvis.indiatimes.com/v1/feeds/toi_plus/site_settings/643526e21443833f0c454615?db_env=published';
#           window.getFromClient(JarvisUrl, function(config){
#             if (config) {
#               const allowedSectionSuricate = (isPrimeUserLayout) ? config?.allowedSurvicatePrimeSections : config?.allowedSurvicateSections
#               loadGtagEvents(config?.isGoogleCampaignActive);
#               loadFBEvents(config?.isFBCampaignActive);
#               loadSurvicateJs(allowedSectionSuricate);
#             }
#           })
#       }
#     };
#   })(
#     window,
#     document,
#     'script',
#   );</script><script type="text/javascript">window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('set', 'linker', {'domains': ['timesofindia.indiatimes.com', 'm.timesofindia.com']});
# gtag('js', new Date());</script><script>if(document.domain.indexOf('indiatimes.com') >= 0){document.domain = 'indiatimes.com';}
# if(document.domain.indexOf('timesofindia.com') >= 0){document.domain = 'timesofindia.com';}</script><script type="text/javascript">TimesGDPR=window.TimesGDPR||{};TimesGDPR.common=window.TimesGDPR.common||{};TimesGDPR.common.getParameterByName=function(b,a){if(!a){a=window.location.href}b=b.replace(/[\[\]]/g,"\\$&");var d=new RegExp("[?&]"+b+"(=([^&#]*)|&|#|$)"),c=d.exec(a);if(!c){return null}if(!c[2]){return""}return decodeURIComponent(c[2].replace(/\+/g," "))};TimesGDPR.common.checkIfPopShouldShow=function(){return !(TimesGDPR.common.getParameterByName("frmapp")==="yes"||TimesGDPR.common.getParameterByName("self")==="1")};TimesGDPR.common.consentModule=(function(){var j="https://timesofindia.indiatimes.com";
# var t=j+"/cookie-policy";var J=j+"/privacy-policy/cookiepolicy/80245266.cms";var L="TOI";var D=function(P){var Q;if(P){Q='<div class="consent-banner  wrapper"><p>We use cookies and other tracking technologies to provide services while browsing the Website to show personalise content and targeted ads, analyse site traffic and understand where our audience is coming from in order to improve your browsing experience on our Website. By continuing to use our Website, you consent to the use of these cookies and accept our Privacy terms. If you wish to see more information about how we process your personal data, please read our <a target="_blank" href="'+t+'"> Cookie Policy </a> and  <a target="_blank" href="'+J+'"> Privacy Policy</a></p>';
# Q+='<a href="javascript://" class="closebtn" id="consent-continue-button">close</a></div>'}else{Q='<div class="consent-banner  wrapper"><h2>Accept the updated privacy &amp; cookie policy</h2>';Q+='<div class="column1" id="consent-prompt"><p>We use cookies and other tracking technologies to provide services in line with the preferences you reveal while browsing the Website to                show personalize content and targeted ads, analyze site traffic<span id="dots">...</span><span id="more">, and understand where our audience is coming from in order to improve your browsing experience on our Website. By continuing to browse              this Website, you consent to the use of these cookies. If you wish to object such processing, please read the instructions described in our';
# Q+='<a target="_blank" href="'+t+'"> Cookie Policy </a>';Q+=" /";Q+='<a target="_blank" href="'+J+'"> Privacy Policy</a></span>';Q+='<a id="read-more" href="javascript:void(0);">Read more</a>';Q+="</p></div>";Q+='<div class="column2">';Q+='<ul><li><button id="consent-continue-button" type="button">Accept</button></li>';Q+="</ul></div>";Q+='<div class="personalisedadsBlk checkbox"><input type="checkbox" active checked name="personalisedads" id="personalisedadsCheckBox" value="1">';Q+='<label for="personalisedadsCheckBox">I agree to see customized ads that are tailor-made to my preferences</label></div>';
# Q+="</div>"}return Q};var C=function(){var P='<div class="consent-banner  wrapper consent-toast-popup"><div class="column1 toastmessage"><p>Our Privacy Policy has been revised. Please review updated  ';P+='<a target="_blank" href="'+J+'">Privacy Policy Here</a>';P+='</p></div><button class="close" id="toast-close-button" type="button""></button></div>';return P};var x={consentHTML:function(P){return D(P)},policyUpdateHTML:function(){return C()},policyUpdateCloseButtonId:"toast-close-button",consentBannerClass:"consent-popup",readMoreBtn: "read-more",consentAgreeButtonId:"consent-continue-button",personalisedAdsCheckBoxId:"personalisedadsCheckBox",consentVersionCookieName:"consent_verison",consentVersionCookieVal:"v1",consentVersionCookieAge:365,consentCookieName:"ckns_policyV2",consentCookieVal:"1",consentCookieAge:365,geoContCookieName:"geo_continent",geoCountryCookieName:"geo_country",geoRegionCookieName:"geo_region",geoRegionCookieAge:3,geoContCookieAge:1,optOutCookieName:"optout",optOutCookieDefaultVal:1,optOutAcceptCookieVal:0,optOutCookieAge:365,consentReqCont:["EU"],consentReqCountryRegions:["US_CA"],domainName:"",columbiaCoookie:"_col_uuid",dynamicCssSrc:"",productCode:"toi-web"};
# var M={cbfn:[],domReady:false,displayPopupCalled:false,postConsent:false,consentAPIstatus:"",consentAPIretryCount:1};var s={consentAPIUrl:"https://etservices2.indiatimes.com/toi/consent/jsonp",consentAPIinput:{consent:{consents:[{agree:true,created:"",dataPoint:{id:5},text:"",updated:""}],productCode:""},primaryId:""}};var h=function(){var P=document.querySelectorAll("."+x.consentBannerClass);if(P.length>0){P[0].style.display="none"};if (window.localStorage) {window.localStorage.setItem('ccpaGdprPopupShown', '1'); window.location.reload(); }};var E=function(){if(M.domReady&&(typeof x.geoDataAvailable!="undefined")&&!M.displayPopupCalled){M.displayPopupCalled=true;
# if(x.isEUuser){document.body.className+=" euuser"}if(x.isEUuser&&false){var Q=f(x.consentCookieName);var P=f(x.consentVersionCookieName);if(!Q){K(false);l();}else{if(P!==x.consentVersionCookieVal){K(true);c();i(x.consentVersionCookieName,x.consentVersionCookieVal,x.domainName,x.consentVersionCookieAge)}}}}};var l=function(){document.getElementById(x.consentAgreeButtonId).onclick=O;document.getElementById(x.readMoreBtn).onclick= readMoreHandler;};var c=function(){document.getElementById(x.policyUpdateCloseButtonId).onclick=h};var r=function(){var Q=document.createElement("link"),P=document.getElementsByTagName("head")[0];
# Q.rel="stylesheet";Q.type="text/css";Q.href=x.dynamicCssSrc;if(typeof G==="function"){if(typeof Q.addEventListener!="undefined"){Q.addEventListener("load",G,false)}else{if(typeof Q.onreadystatechange!="undefined"){Q.onreadystatechange=function(){d(Q,G)}}else{setTimeout(G,100)}}}P.appendChild(Q)};var G=function(){E()};var m=function(){var Q=f(x.geoContCookieName);var T=f(x.geoCountryCookieName);var R=f(x.geoRegionCookieName);if(typeof window.geoinfo=="undefined"&&(!Q||!T||!R)){var S=document.createElement("script"),P=document.getElementsByTagName("head")[0];
# ...
#             script.defer = true;
#             document.body.appendChild(script);
#           // }else{
#           //   triggerGA('EU_US_User');
#           // }
#         })
#       }else{
#         // triggerGA('Gdpr_consent');
#       }
#     }
#     else{
#       // triggerGA('AffiliatePage');
#     }
#
#     if(!false && true){
#       scripts.push(WebDomainName + '/locateservice_js/minify-1,version-14.cms')
#     }
#
#     scripts.push(WebDomainName + '/aqiscript/minify-1,version-2.cms');
#     scripts = scripts.concat(afterAdsScriptArray);
#
#     scripts.forEach(function(url) {
#         var script = document.createElement('script');
#         script.type="text/javascript";
#         if(["https://onelinksmartscript.appsflyer.com/onelink-smart-script-latest.js"].includes(url)){
#           window._toi_script_promises[url] = new Promise(function(resolve,reject){
#             script.onload = function(){
#               const script_load_event  = new CustomEvent('afterAdsScriptLoaded', {detail:{'url': url}});
#               window.dispatchEvent(script_load_event);
#               resolve();
#             }
#             script.onerror = function(){
#               reject();
#             }
#           });
#         }
#         script.src = url;
#         script.async = true;
#         script.defer = true;
#         document.body.appendChild(script);
#       });
#     }
#   }
#   </script><script type="text/javascript">!function(){window.TimesApps=window.TimesApps||{};let{TimesApps:a}=window;a.ResetFirstFoldScroll=a.ResetFirstFoldScroll||function(){try{let c=document.getElementById("_scrollanchor_"),a=document.getElementById("app")||document.getElementById("App")||document.getElementById("APP");if(a instanceof HTMLElement&&c instanceof HTMLElement&&window){let b=c.getBoundingClientRect();return b.bottom>=(window.innerHeight||document.documentElement.clientHeight)&&b.right<=(window.innerWidth||document.documentElement.clientWidth)&&(a.style.height=b.bottom+100+"px",a.style.overflowY="hidden"),function(){a.style.height="initial",a.style.overflowY="initial"}}}catch(d){}},a.ResetFirstFoldScroll=a.ResetFirstFoldScroll(),a.globalIntersectObserver=a.globalIntersectObserver||function(){if(!("IntersectionObserver"in window))return!1;let a=new IntersectionObserver(b=>{b.forEach(b=>{(b.isIntersecting||b.intersectionRatio>0)&&(b.target&&b.target instanceof Image&&b.target.src!==b.target.dataset.src&&(b.target.src=b.target.dataset.src),a.unobserve(b.target))})},{rootMargin:"100px",threshold:.15});return document.querySelectorAll("img[data-api-prerender]").forEach(b=>a.observe(b)),a},a.globalIntersectObserver=a.globalIntersectObserver()}()</script><script async="" src="https://timesofindia.indiatimes.com/popup_manager_priority.cms"></script><script type="text/javascript">
#   (function(){
#     if(false){
#       var _chunks = ['https://geoapi.indiatimes.com/?cb']
#     } else {
#       var _chunks = ['https://geoapi.indiatimes.com/?cb','https://assets.toiimg.com/assets/bootstrap-modern_es6_module.c20757c9.js','https://assets.toiimg.com/assets/50886_es6_module.daea1bfe.js','https://assets.toiimg.com/assets/73935_es6_module.8d61b5d9.js','https://assets.toiimg.com/assets/client_es6_module.cefb0f33.js','https://assets.toiimg.com/assets/bootstrap.db5391ae.js','https://assets.toiimg.com/assets/91058.29f01614.js','https://assets.toiimg.com/assets/39916.9af89458.js','https://assets.toiimg.com/assets/73935.33e65894.js','https://assets.toiimg.com/assets/client.5a741e96.js','https://assets.toiimg.com/assets/ushomedesktop_es6_module.bf1d6629.chunk.js','https://assets.toiimg.com/assets/ushomedesktop.6ff89861.chunk.js'];
#     }
#     var _stylechunks = ['https://assets.toiimg.com/assets/11024.60ac2bc2.chunk.css','https://assets.toiimg.com/assets/13400.00098eb8.chunk.css','https://assets.toiimg.com/assets/19451.04fb67bb.chunk.css','https://assets.toiimg.com/assets/73971.a9476bbb.chunk.css','https://assets.toiimg.com/assets/ushomedesktop.4d51d22c.chunk.css'];
#     window._delayedResourcesLoaded = false;
#     var _callDelayedResourcesImmediately = false || false || false || false;
#
#     function loadStateJSON(src, callOnLoad) {
#       fetch(src)
#         .then(response => {
#           if (!response.ok) {
#             throw new Error('Network response was not ok');
#           }
#           return response.json();
#         })
#         .then(data => {
#           window.App = data;
#           callOnLoad();
#         })
#         .catch(error => {
#           console.error('There was a problem with the fetch operation:', error);
#         });
#     }
#
#     function loadResources() {
#         if(!false && typeof loadCSS === 'function') {
#           _stylechunks.forEach(function(src) {
#             loadCSS(src);
#           });
#         }
#         var callOnBrowserIdle = function (callback) {
#             if(callback && typeof callback === 'function'){
#               if (typeof window.requestIdleCallback === "function") {
#                 window.requestIdleCallback(callback);
#               } else {
#                 setTimeout(callback,0)
#               }
#             }
#         };
#
#         function loadJs(src) {
#           var script = document.createElement('script');
#           script.type = "text/javascript";
#           script.src = src;
#           script.async = true;
#           script.defer = true;
#           if(src && src.includes('_es6_module')) {
#               script.type = "module";
#             } else if(!(src && (src.includes('geoapi')))) {
#               script.noModule = true;
#             }
#           document.body.appendChild(script);
#         }
#         _chunks.forEach(function(src) {
#           setTimeout(function(){
#               loadJs(src)
#             },0)
#           });
#
#         if(typeof window !== 'undefined' && window.TimesApps) {
#             var functionsToCall = ["ResetFirstFoldScroll", "initCLSHandling"];
#             var functionsToCallWhenIdle = [
#               "loadGrowthRXsdk",
#               "popupManger2",
#               "showInterstitial",
#               "loadScriptsOnceAdsReady",
#               "loadTpSdk",
#               "toiPlusEvents"
#             ];
#             if(false) {
#               functionsToCallWhenIdle = [
#                 "loadScriptsOnceAdsReady",
#               ];
#             }
#             var callTimesAppsFn = function (fnName, useIdleCallback) {
#               if (typeof window.TimesApps[fnName] === "function") {
#                 if (useIdleCallback) {
#                   callOnBrowserIdle(window.TimesApps[fnName]);
#                 } else {
#                   window.TimesApps[fnName]();
#                 }
#               }
#             };
#             functionsToCall.forEach(function (fn) {
#                 callTimesAppsFn(fn, false);
#             });
#             functionsToCallWhenIdle.forEach(function (fn) {
#                 callTimesAppsFn(fn, true);
#             });
#         }
#     }
#
#     window._loadDelayedResources = function(){
#       // console.log('Document Ready State', document.readyState);
#       if (!_delayedResourcesLoaded && typeof window !== 'undefined') {
#         _delayedResourcesLoaded = true;
#         debugLogs('########## Calling _loadDelayedResources in React App: ', (performance.now()/1000).toFixed(2)+'seconds');
#         if(false) {
#           loadStateJSON("", loadResources);
#         } else {
#           loadResources();
#         }
#
#       }
#     }
#
#     if(_callDelayedResourcesImmediately){
#       // TODO: Trigger the event for delayed load in ga4
#       window._loadDelayedResources();
#     }
#     else {
#       // Commented due to ads impacted due to it.
#       // document.addEventListener("DOMContentLoaded", () => {
#       //   setTimeout(window._loadDelayedResources, 0);
#       // });
#       setTimeout(() => {
#         debugLogs('########## Calling _loadDelayedResources via settimeout - fail fallback: ', (performance.now()/1000).toFixed(2)+'seconds');
#         window._loadDelayedResources();
#         // TODO: Trigger the event for delayed load in ga4
#       }, 6000);
#     }
#     })();</script><script async="">
# (function() {
#   if (typeof window !== 'undefined') {
#     window._dfpObj = window._dfpObj || {};
#     var _adShieldObj = {};
#     window._dfpObj.displayShieldExecuted = false;
#     window._dfpObj.displayBlkrEnabled = null;
#
#     _adShieldObj.setCookie = function(name, value, minutes) {
#       var date = new Date();
#       date.setTime(date.getTime() + minutes * 60 * 1000);
#       document.cookie =
#         name +
#         '=' +
#         value +
#         ';expires=' +
#         date.toUTCString() +
#         ';path=/;domain=.' +
#         document.domain;
#     };
#     _adShieldObj.getCookie = function(cname) {
#       var name = cname + '=';
#       var ca = document.cookie.split(';');
#       for (var i = 0; i < ca.length; i++) {
#         var c = ca[i];
#         while (c.charAt(0) == ' ') {
#           c = c.substring(1);
#         }
#         if (c.indexOf(name) == 0) {
#           return c.substring(name.length, c.length);
#         }
#       }
#       return '';
#     };
#
#     window._dfpObj.displayShield = function() {
#       var script = document.createElement('script');
#       script.type = 'text/javascript';
#       script.setAttribute('onload', "let l=!1,k=Math.random().toString(),a='html-load.com';window.addEventListener('message',e=>{e.data===k+'_as_res'&&(l=!0)}),window.postMessage(k+'_as_req','*'),new Promise(e=>{let t=Math.random().toString(),r=Math.random().toString();window.addEventListener('message',e=>e.data===t&&window.postMessage(r,'*')),window.addEventListener('message',t=>t.data===r&&e()),window.postMessage(t,'*')}).then(()=>{window.setTimeout(()=>{if(!l){setInterval(()=>document.querySelectorAll('link,style').forEach((e)=>e.remove()),100);let e=atob('RmFpbGVkIHRvIGxvYWQgd2Vic2l0ZSBwcm9wZXJseSBzaW5jZSA')+a+atob('IGlzIGJsb2NrZWQuIFBsZWFzZSBhbGxvdyA')+a;throw alert(e),fetch('https://error-report.com/report?type=loader_light&url='+btoa(location.href)+'&error='+btoa(e),{method:'POST'}).then(e=>e.text()).then(t=>{let r=document.createElement('iframe');r.src='https://report.error-report.com/modal?eventId='+t+'&error='+btoa(e)+'&domain='+a,r.setAttribute('style','width: 100vw; height: 100vh; z-index: 2147483647; position: fixed; left: 0; top: 0;'),document.body.appendChild(r);let o=e=>{'close-error-report'===e.data&&(r.remove(),window.removeEventListener('message',o))};window.addEventListener('message',o)}).catch(e=>{confirm(navigator.language.toLowerCase().startsWith('ko')?decodeURIComponent(escape(atob(''))):atob(''))?location.href='https://report.error-report.com/modal?eventId=&error='+btoa(e.toString())+'&domain='+a:location.reload()}),Error(e)}},1e3)});", );
#       script.setAttribute('onerror', "let e=document.getElementById('DEWQnTTgxDI'),t=document.createElement('script');for(let r=0;r<e.attributes.length;r++)t.setAttribute(e.attributes[r].name,e.attributes[r].value);let s=new window.URL(e.src),a=['html-load.com','fb.html-load.com','content-loader.com','fb.content-loader.com'];if(void 0===window.as_retry&&(window.as_retry=0),window.as_retry>=a.length){setInterval(()=>document.querySelectorAll('link,style').forEach((e)=>e.remove()),100);let o=atob('RmFpbGVkIHRvIGxvYWQgd2Vic2l0ZSBwcm9wZXJseSBzaW5jZSA')+a[0]+atob('IGlzIGJsb2NrZWQuIFBsZWFzZSBhbGxvdyA')+a[0];throw alert(o),fetch('https://error-report.com/report?type=loader_light&url='+btoa(location.href)+'&error='+btoa(o),{method:'POST'}).then(e=>e.text()).then(e=>{let r=document.createElement('iframe');r.src='https://report.error-report.com/modal?eventId='+e+'&error='+btoa(o)+'&domain='+a[0],r.setAttribute('style','width: 100vw; height: 100vh; z-index: 2147483647; position: fixed; left: 0; top: 0;'),document.body.appendChild(r);let f=e=>{'close-error-report'===e.data&&(r.remove(),window.removeEventListener('message',f))};window.addEventListener('message',f)}).catch(o=>{let l=navigator.language.toLowerCase().startsWith('ko')?decodeURIComponent(escape(atob(''))):atob('');confirm(l)?location.href='https://report.error-report.com/modal?eventId=&error='+btoa(o.toString())+'&domain='+a[0]:location.reload()}),Error(o)}s.host=a[window.as_retry++],t.setAttribute('src',s.href),t.setAttribute('as-async','true'),e.setAttribute('id', e.getAttribute('id')+'_'),e.parentNode.insertBefore(t,e),e.remove();", );
#       script.src = 'https://html-load.com/loader.min.js';
#       script.data = 'ithc1r8q8e878b8v808e1p8efy81108k3e8iy28y8e808784y8i801m8i8i878y8e387848r8i28y8e878i8g8712z80808y8e31me8i728y8e8bk8j0871pky8b108k8y8e8sf12y81108k8s8e1z89';
#       script.id = 'DEWQnTTgxDI';
#       script.setAttribute('data-sdk', '1.0.5');
#       script.setAttribute('data-cfasync', 'false');
#       document.head.appendChild(script);
#     }
#     window._dfpObj.prebidAvailable = function() {
#       setTimeout(function() {
#         if (
#           (window.pbjs && typeof window.pbjs.requestBids === 'function') ||
#           (window.PWT && typeof window.PWT.requestBids === 'function')
#         )
#           return;
#         window.DisplayBlkrDetected('prebidBlocked');
#       }, 4000);
#     };
#     window.DisplayBlkrDetected = function(type) {
#       window._dfpObj.displayBlkrEnabled = _adShieldObj.getCookie('displayRender')
#         ? _adShieldObj.getCookie('displayRender')
#         : null;
#       if (type === 'prebidBlocked') window._dfpObj.displayBlkrEnabled = 0;
#       if (
#         (parseInt(window._dfpObj.displayBlkrEnabled) === 0 ||
#           window.prebidBlocked) &&
#         !window._dfpObj.displayShieldExecuted
#       ) {
#         _adShieldObj.setCookie('displayRender', 0, 24 * 60 * 30);
#         window._dfpObj.displayShield();
#         window._dfpObj.displayShieldExecuted = true;
#       } else {
#         window._dfpObj.prebidAvailable();
#       }
#     };
#     window.DisplayBlkrDetected('default');
#     window._dfpObj.displayBlkrRender = true;
#     window.googletag.cmd.push(function() {
#       window.googletag
#         .pubads()
#         .addEventListener('slotRenderEnded', function(event) {
#           if (window._dfpObj.displayBlkrRender && event.isEmpty) {
#             _adShieldObj.setCookie('displayRender', 0, 24 * 60 * 30);
#             window._dfpObj.displayBlkrRender = false;
#           }
#           if (!event.isEmpty)
#             _adShieldObj.setCookie('displayRender', 1, 24 * 60 * 30);
#         });
#     });
#   }
# })();
# </script><noscript> <img height="1" src="https://www.facebook.com/tr?id=593671331875494&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P3PMSJN" style="display:none;visibility:hidden" width="0"></iframe></noscript><script type="application/ld+json"> { "@context": "https://schema.org", "@type": "WebSite", "name": "Times of India", "alternateName" : "TOI", "url":"https://timesofindia.indiatimes.com", "potentialAction":{ "@type":"SearchAction", "target": { "@type": "EntryPoint", "urlTemplate": "https://timesofindia.indiatimes.com/topic/{search_term_string}" }, "query-input": "required name=search_term_string" } } </script></body></html>

# %%
#Extracting Data (label_names,label_link, img_urls)
label_names=[]
label_link=[]
img_urls=[]



for i in data.find_all('a'):
  labels=i.get_text()
  links=i.get('href')
  desc=i.find('p')
  img_link=i.find('img')
  img_src=img_link.get('src') if img_link else None




  label_names.append(labels)
  label_link.append(links)
  img_urls.append(img_src)

# %%
#Extracting Descriptions
descriptions=[]
desc_1 = data.find_all("p")
desc_2 = data.find_all("figcaption")
desc_3 = data.find_all("span")

# %%
desc_1
# Out:
# [<p>Chhaava’s excellence lies in its terrific climax. You just wish the film relied and trusted its solid story more than Rahman's music, which largely feels out of place.</p>,
#  <p>Dhoom Dhaam is a fast-paced rollercoaster of action, comedy, and mystery, powered by Yami Gautam Dhar and Pratik Gandhi’s electric chemistry.</p>,
#  <p>Despite its convoluted plot and occasional pacing issues, Brave New World delivers thrilling aerial battles and hand-to-hand combats, strong performances, and enough spectacle to entertain superhero</p>,
#  <p class="ObA_k">10 quotes to inspire and motivate you</p>,
#  <p class="ObA_k">10 health benefits of chewing cloves daily</p>,
#  <p class="ObA_k">10 things parents should never do in the morning before sending kids to school</p>,
#  <p class="ObA_k">10 powerful ways to detox and reset your mind</p>,
#  <p class="ObA_k">10 birds that eat meat and other animals</p>,
#  <p class="ObA_k">10 exotic animals to spot inside Kashmir's Dachigam National Park</p>,
#  <p class="ObA_k">How to make South Indian Paneer Butter Masala Dosa for breakfast</p>,
#  <p class="ObA_k">​10 ancient animals that still exist</p>]

# %%
desc_2
# Out:
# [<figcaption>A decade ago, he was dragged out — now, Vijender Gupta will run the show as Delhi House speaker</figcaption>,
#  <figcaption class="">After Trump's Indian polls expose, BJP shares old clips of PM blaming Cong</figcaption>,
#  <figcaption class="">Pride of India, Asia’s first vertical-lift sea bridge set to open in TN</figcaption>,
#  <figcaption class="suxSu"><div class="g2Qrw FbRtQ"></div>Will work towards mission of Viksit Delhi, says CM Rekha Gupta</figcaption>,
#  <figcaption class="">'Not safe in our country': Deportees from US cry for help from Panama hotel</figcaption>,
#  <figcaption class="">Everest snow cover has retreated by 490ft in 1.5 months, says study</figcaption>,
#  <figcaption class="">Champions Trophy: 50-over cricket’s midlife crisis, with India twist</figcaption>,
#  <figcaption class="suxSu"><div class="g2Qrw FbRtQ"></div>IND vs BAN Live: Hridoy-Jaker stand frustrate India in Dubai</figcaption>,
#  <figcaption class="">Tesla likely to import cars from Germany, skip China</figcaption>,
#  <figcaption class="">Watch: How Rohit Sharma messed up Axar's hat-trick chance</figcaption>,
#  <figcaption class="">'Dragged out of lift, assaulted': Woman attacks minor over pet dog objection</figcaption>,
#  <figcaption class="">Gurgaon lawyer held for Noida boy’s death in celebratory firing</figcaption>,
#  <figcaption class="">Police receive email threat to bomb Maharashtra deputy CM Shinde’s car</figcaption>,
#  <figcaption class="">'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row</figcaption>,
#  <figcaption class="">California judge shoots wife during argument while watching 'Breaking Bad'</figcaption>,
#  <figcaption class="">Shopping: Discounts Up to 60% Off on Gadgets &amp; Electronics</figcaption>,
#  <figcaption class="">NASA leadership changes spark uncertainty over the future of the US Moon program</figcaption>,
#  <figcaption class="">Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for</figcaption>,
#  <figcaption class="">Love &amp; Dating Horoscope for February 20, 2025</figcaption>,
#  <figcaption class="">Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles</figcaption>,
#  <figcaption class="">Horoscope Tomorrow, February 21, 2025: Your zodiac insights await</figcaption>,
#  <figcaption class="">Australian children bypass social media age limit restriction as landmark ban nears: Report</figcaption>,
#  <figcaption class="">Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City</figcaption>,
#  <figcaption class="">Trump Doubles Down On 'False' Condom Claim; '$100 Million Designated By US To Buy...'</figcaption>,
#  <figcaption class="">Argentina Court Slams Liam Payne's Family, Acquits Roger Nores On 'These' Grounds | WATCH</figcaption>,
#  <figcaption class="">Liam Payne Case: Argentina Court Acquits Roger Nores &amp; 2 Hotel Employees Of All Charges</figcaption>,
#  <figcaption class="">Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail</figcaption>,
#  <figcaption class="">Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review</figcaption>,
#  <figcaption class="">Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian Americans in entertainment sector</figcaption>,
#  <figcaption class="">Horoscope Today: Astrological Predictions for February 20, 2025</figcaption>,
#  <figcaption class="">If 300-ft asteroid hits earth in 2032, Mumbai and Kolkata at high risk</figcaption>,
#  <figcaption class="">Trump is upending Western-led world order and India can benefit from it</figcaption>,
#  <figcaption class="">Why India doesn't need ultra-pricey F-35s &amp; what it should get instead</figcaption>,
#  <figcaption>Bhumi recalls falling on stage in UP in front of 30,000 people</figcaption>,
#  <figcaption class="">Ministry of I&amp;B issues an advisory to OTT platforms</figcaption>,
#  <figcaption class="">Arjun REACTS to people judging him for surname-looks</figcaption>,
#  <figcaption class="">Bollywood Actors Who Love Painting</figcaption>,
#  <figcaption class="">Celebrity MasterChef: Net worth of the contestants</figcaption>,
#  <figcaption class="pf60w">Dia Mirza's ethnic wear</figcaption>,
#  <figcaption class="pf60w">Sonakshi-Zaheer's adorable pics</figcaption>,
#  <figcaption class="pf60w">Amyra Dastur's golden glamour</figcaption>,
#  <figcaption class="pf60w">Tamannaah's animal print outfit</figcaption>,
#  <figcaption class="pf60w">Madhuri's white Patola saree</figcaption>,
#  <figcaption class="pf60w">Sanya redefines power dressing</figcaption>,
#  <figcaption class="pf60w">B-Town divas welcome Bappa in style</figcaption>,
#  <figcaption class="pf60w">Urmila Matondkar the timeless beauty</figcaption>,
#  <figcaption class="pf60w">Ananya Panday's style file</figcaption>,
#  <figcaption>Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?</figcaption>,
#  <figcaption class="">Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?</figcaption>,
#  <figcaption class="">Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage &amp; Over-the-Top Acting</figcaption>,
#  <figcaption class="">Exclusive: Saba Azad &amp; Saqib Saleem Address Importance Of Self-Censorship &amp; Side Effects Of Social Media</figcaption>,
#  <figcaption class="">Blake Lively Accuses Justin Baldoni of On-Set Misconduct – Shocking Allegations Surface!</figcaption>,
#  <figcaption class="">Supreme Court Hits Ranveer For ‘Perverted’ Remarks; Passport Seized, Travel Blocked - Calls Out His ‘Dirty Mind’</figcaption>,
#  <figcaption class="">Heartbreaking Goodbye: Kim Sae-Ron’s Emotional Funeral Leaves K-Stars in Tears</figcaption>,
#  <figcaption>Man locks ill mother at home, takes wife, kids to Maha Kumbh for holy dip</figcaption>,
#  <figcaption class="">'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India</figcaption>,
#  <figcaption class="">'Disturbing': SC on Lokpal order which entertained complaints against sitting HC judges</figcaption>,
#  <figcaption class="">Ramdev blocks Bryan Johnson on X over Haridwar air quality comment on Patanjali post</figcaption>,
#  <figcaption class="">‘Nahi nahi’: Delhi CM-designate Rekha Gupta on staying in 'Sheesh Mahal'</figcaption>,
#  <figcaption>Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail</figcaption>,
#  <figcaption class="">Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail</figcaption>,
#  <figcaption class="">Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review</figcaption>,
#  <figcaption class="">Hungary Against Ukraine’s EU Bid; Orban Says ‘Entry Will Burden Members’ | Details</figcaption>,
#  <figcaption class="">‘Trump Speaks For Himself’: Senate Majority Leader Comes In Support Of Zelensky</figcaption>,
#  <figcaption class="">Barbie Hsu's Ex Husband Wang Xiaofei Sparks Outrage With Contrasting Actions In China</figcaption>,
#  <figcaption class="">Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage &amp; Over-the-Top Acting</figcaption>,
#  <figcaption>Gurgaon lawyer held for Noida boy’s death in celebratory firing</figcaption>,
#  <figcaption>IND vs BAN Live: Shami breaks Towhid -Jaker stand</figcaption>,
#  <figcaption class="">Champions Trophy: India's predicted XI vs Bangladesh | What Rohit Sharma said in the press</figcaption>,
#  <figcaption class="">Mohammad Amir Exclusive: Champions Trophy hopes, India's absence &amp; retirement talk</figcaption>,
#  <figcaption class="">MS Dhoni shares his secrets for a stress-free existence</figcaption>,
#  <figcaption class="">England hope 'Bazball' fires in Champions Trophy</figcaption>,
#  <figcaption class="">Watch: How Rohit Sharma messed up Axar's hat-trick chance</figcaption>,
#  <figcaption class="">Had doubts if I'd ever play for India again: Mohammed Shami</figcaption>,
#  <figcaption class="">Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”</figcaption>,
#  <figcaption class="">Police nab ATM scammer with Rs. 17.9 Lakh; find out where the money went</figcaption>,
#  <figcaption class="">Teen dies after self-injecting butterfly remains; here's what happened</figcaption>,
#  <figcaption class="">IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed</figcaption>,
#  <figcaption class="">​11 mysteries on the Earth that remain unsolved​</figcaption>,
#  <figcaption class="">Who is Elon Musk? Why is he so much in the news suddenly</figcaption>,
#  <figcaption>The Worst Planet for a Vacation – Where Even Travel Insurance Won’t Help</figcaption>,
#  <figcaption class="">From swipes to soulmates: 5 Zodiac signs that shine in online dating</figcaption>,
#  <figcaption class="">If Planets Were Yoga Instructors, Who Would Be the Most Annoying?</figcaption>,
#  <figcaption class="">Horoscope Today: Astrological Predictions for February 20, 2025</figcaption>,
#  <figcaption class="">5 Zodiac Sign Men Who Bring Unmatched Luck to Their Wives</figcaption>,
#  <figcaption>'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot</figcaption>,
#  <figcaption>India auto component industry revenues to expand 8-10% in 2025-26: ICRA</figcaption>,
#  <figcaption class="">iPhone parts maker Murata eyes India base</figcaption>,
#  <figcaption class="">ICAI: Disciplinary action against 241 CAs, a new record</figcaption>,
#  <figcaption class="">EV policy: Companies require Rs 2,500 crore sales in 2nd year</figcaption>,
#  <figcaption class="">High frequency indicators point to economic recovery: RBI</figcaption>,
#  <figcaption class="">This protein-packed Indian egg dish is among world's '50 best egg dishes'</figcaption>,
#  <figcaption class="">How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh</figcaption>,
#  <figcaption class="">How to make South Indian Appe with dosa batter for breakfast</figcaption>,
#  <figcaption class="">10 protein-packed comforting dishes made with chickpeas</figcaption>,
#  <figcaption class="">​3 effortless ways to set restaurant-style curd​</figcaption>,
#  <figcaption class="">How to make Dhaba-style Champaran Chicken Handi at home</figcaption>,
#  <figcaption>Jaya Bachchan's regal Ajrakh ensemble</figcaption>,
#  <figcaption>Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for</figcaption>,
#  <figcaption>10 best quotes on relationships by Sudha Murty</figcaption>,
#  <figcaption>This protein-packed Indian egg dish is among world's '50 best egg dishes'</figcaption>,
#  <figcaption>How to use Honey for instant hair growth</figcaption>,
#  <figcaption>6 types of people every child will face in life and how to deal with them</figcaption>,
#  <figcaption>8 most important lessons to take from the Bhagwad Gita</figcaption>,
#  <figcaption>5 natural sources of Biotin which encourage hair growth</figcaption>,
#  <figcaption>How to grow Cherry tomatoes in the balcony in under 90 days</figcaption>,
#  <figcaption class="">5 designer essential bags every 'Momager' should have</figcaption>,
#  <figcaption class="">10 things parents should never do in the morning before sending kids to school</figcaption>,
#  <figcaption class="">10 timeless lines from Mirza Ghalib's shayaris</figcaption>,
#  <figcaption class="">7 fruits that help a person lose extra fat near the belly</figcaption>,
#  <figcaption class="">6 benefits of drinking ginger-turmeric tea in the morning</figcaption>,
#  <figcaption class="">Sanya Malhotra approved trendy blouse designs</figcaption>,
#  <figcaption>UK Hindus protest Islamophobia panel, say tackle all hatred</figcaption>]

# %%
desc_3
# Out:
# [<span class="KGWPT">Edition</span>,
#  <span>US</span>,
#  <span class="logout-window"><span class="login user-notloggedin">Sign In</span></span>,
#  <span class="login user-notloggedin">Sign In</span>,
#  <span class="Q5T6S"></span>,
#  <span class="OG1TB" data-newga="#NavBar-Search-Click#" data-setgacategory="true"></span>,
#  <span></span>,
#  <span>In the <h1>News</h1></span>,
#  <span class="zVNTF"></span>,
#  <span>Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government</span>,
#  <span>MS Dhoni shares his secrets for a stress-free existence</span>,
#  <span>Are dating apps the new job portals? Woman uses Hinge for job search and shares viral chat screenshots</span>,
#  <span>IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed</span>,
#  <span>'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot</span>,
#  <span>Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”</span>,
#  <span>Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!</span>,
#  <span>Champions Trophy: South Africa aim to shed chokers tag against Afghanistan</span>,
#  <span>Are expecting mothers in India at risk of Vitamin D deficiency during winter?</span>,
#  <span>Egg vs Paneer: Which one is a better source of protein for weight loss</span>,
#  <span>Trending News</span>,
#  <span class="Tsj9M"></span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Entertainment</span>,
#  <span>Shenaz loses a brand following Ranveer's controversy</span>,
#  <span>When Ranbir left Rashmika crying on sets of Animal</span>,
#  <span>Aadar calls past relationships 'time pass', faces backlash</span>,
#  <span>What’s happening with the OTT deal for Sky Force?</span>,
#  <span>Nicole Kidman's 'Babygirl' CENSORED in India</span>,
#  <span>Vicky’s climax look in Chhaava took over four hours of make-up</span>,
#  <span>6 benefits of drinking Okra water with lemon every morning</span>,
#  <span>Optical illusion: What you see shows how you handle stress</span>,
#  <span>Zahan Kapoor says shooting with Shah Rukh Khan was 'difficult'</span>,
#  <span>Exclusive: Rozlyn shares PET scan reports with Hina's name on it</span>,
#  <span>Munmun shares a hilarious video dancing to Govinda’s song</span>,
#  <span>MasterChef: Farah, Ranveer and Vikas praise Gaurav's Dish</span>,
#  <span>Kaveri Kapur: 'I was happy when my parents got divorced'</span>,
#  <span>Vishal slams outrage over Samay and Ranveer controversy</span>,
#  <span class="xhx_z">Etimes Photos</span>,
#  <span class="xhx_z">Reviews</span>,
#  <span>Critic Rating</span>,
#  <span class="FPU4P">3.5</span>,
#  <span>Critic Rating</span>,
#  <span class="FPU4P">3.5</span>,
#  <span>Critic Rating</span>,
#  <span class="FPU4P">3.0</span>,
#  <span>In focus</span>,
#  <span class="xhx_z">Videos</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">India</span>,
#  <span>Who are the 6 cabinet ministers sworn in with Rekha Gupta in Delhi?</span>,
#  <span>Rekha Gupta takes oath as Delhi CM in presence of PM Modi, top NDA leaders</span>,
#  <span>Tribunals can’t overturn its own finding on Assam foreigners: SC</span>,
#  <span>SC adjourns hearing on challenge to CEC, EC selection law; hearings on pre-fixed cases consume bench’s judicial schedule</span>,
#  <span>'Arvind Kejriwal will have to spend most of his time in jail': BJP's Delhi minister-pick Manjinder Singh Sirsa</span>,
#  <span>Trump admits to poll interference in India, BJP shares PM's clips to pin blame on Congress</span>,
#  <span>UP Budget 2025 is dedicated to Sanatan culture of India: Yogi Adityanath</span>,
#  <span>'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row</span>,
#  <span>In pics: Meet the newly sworn-in cabinet of Delhi assembly</span>,
#  <span class="xhx_z">TOI Videos</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">City</span>,
#  <span>In picking Rekha Gupta for Delhi CM's post, RSS student wing strikes again</span>,
#  <span>HC seeks Uttarakhand govt's reply as UCC form asks for live-in couples’ past info</span>,
#  <span>As oven deadline looms, Maharashtra neta seeks heritage tag for Irani bakeries</span>,
#  <span>Youth who entered Shah Rukh Khan's bungalow 'Mannat' in 2023 caught for burglary in Gujarat</span>,
#  <span>Delhi CM's oath-taking today; BJP pulls out all stops to make it a grand affair</span>,
#  <span>Wife, ‘lover’ held for killing man pursuing her rape case in UP court</span>,
#  <span>Uttarakhand to ban outsiders from buying agri land</span>,
#  <span>Planned drama, says Muda scam case petitioner as Lokayukta gives Siddaramaiah, his wife clean chit</span>,
#  <span>Arvind Kejriwal, Atishi among those to congratulate Delhi CM-designate Rekha Gupta</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Sports</span>,
#  <span>ICC approves Imam-ul-Haq as Fakhar's replacement in Pak squad</span>,
#  <span>'Thoda aur bhaiya' - Samson's cute reaction to Dhoni's IPL career</span>,
#  <span>Dominant NZ crush Pakistan in Champions Trophy opener</span>,
#  <span>CT Digest: India open campaign after Pakistan's sorry start</span>,
#  <span>India's spin puzzle: Why Axar, Jadeja are irreplaceable in Champions Trophy plans</span>,
#  <span>Jerk Fox</span>,
#  <span>Josh Allen</span>,
#  <span>Patrick Mahomes</span>,
#  <span>Jimmy Butler</span>,
#  <span>Luka Doncic</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Trending</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Visual Stories</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Astrology</span>,
#  <span>Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City</span>,
#  <span>Which Zodiac Would Have the Best Theme Park?</span>,
#  <span>Beyond swipes: 5 Zodiac signs that crave deep, real-life love</span>,
#  <span>Love &amp; Dating Horoscope for February 20, 2025</span>,
#  <span>Which Zodiac Would Have the Most Aesthetic Instagram Feed?</span>,
#  <span>Best Husbands by Date of Birth – Because the Stars Have a Type</span>,
#  <span>Horoscope Tomorrow, February 21, 2025: Your zodiac insights await</span>,
#  <span>7 Things to Absolutely Avoid During Shivratri – Unless Chaos is the Goal</span>,
#  <span>Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">US News</span>,
#  <span>Who is Leland Dudek? Pro-DOGE ‘anti-fraud expert’ takes over as SSA chief after Michelle King’s exit</span>,
#  <span>'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India</span>,
#  <span>California judge shoots wife during argument while watching 'Breaking Bad'</span>,
#  <span>Elon Musk 'misinterprets' Social Security data; Experts say millions of dead not receiving benefits</span>,
#  <span>Watch: Mississippi lieutenant governor Delbert Hosemann collapses on Senate podium while giving speech</span>,
#  <span>Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government</span>,
#  <span>Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian-Americans in entertainment sector</span>,
#  <span>How FBI lead Kash Patel stands to make millions from Shein the Chinese company</span>,
#  <span>Donald Trump wants his new Air Force One jets fast: ‘Boeing's been building this thing forever’</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Business</span>,
#  <span>GenNext less focused on building companies: Uday Kotak</span>,
#  <span>Automobiles on government's list for trade talks with US</span>,
#  <span>Irdai forms committee to review Insurance Act</span>,
#  <span>Tesla likely to import cars from Germany, skip China</span>,
#  <span>Salary hikes to be flat at 9.2%: Survey</span>,
#  <span>UPI users take note! Google Pay introduces convenience fee for these transactions</span>,
#  <span>Why India may raise GST on cigarettes and other tobacco products</span>,
#  <span>Top stocks to buy today: Stock recommendations for February 20, 2025</span>,
#  <span>Stock market today: BSE Sensex opens over 300 points down; Nifty50 below 22,900</span>,
#  <span>Axis Bank</span>,
#  <span>Provident Fund</span>,
#  <span>Income Tax Slabs</span>,
#  <span>GST</span>,
#  <span>Fixed Deposit rates</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Recipes</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Lifestyle</span>,
#  <span class="xhx_z">Style</span>,
#  <span>Sanya Malhotra’s vintage outfit roars heritage</span>,
#  <span>5 celebs who grabbed eyeballs with distressed looks</span>,
#  <span class="xhx_z">Health &amp; Fitness</span>,
#  <span>Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!</span>,
#  <span>Egg vs Paneer: Which one is a better source of protein for weight loss</span>,
#  <span class="xhx_z">Relationship</span>,
#  <span>Personality Test: Your foot arch reveals if you are grounded or a free spirit</span>,
#  <span>Meet King Charles III's dashing bodyguard, whom royal fans compare to James Bond</span>,
#  <span class="xhx_z">Food</span>,
#  <span>How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh</span>,
#  <span>How to make South Indian Appe with dosa batter for breakfast</span>,
#  <span class="xhx_z">Beauty</span>,
#  <span>'Mrs.' actress Sanya Malhotra's curly hair routine revealed</span>,
#  <span>Can Henna or Mehendi increase hair growth?</span>,
#  <span class="xhx_z">Parenting</span>,
#  <span>10 morning habits successful kids are encouraged to follow</span>,
#  <span>Baby names inspired by Shreenathji</span>,
#  <span class="xhx_z">Books</span>,
#  <span>10 timeless lines from Mirza Ghalib's shayaris</span>,
#  <span>8 books that help magically improve relationships and love issues</span>,
#  <span class="xhx_z">Videos</span>,
#  <span>Control Your Senses, Gain Knowledge, Attain Peace: Bhagavad Gita, Chapter 4.39</span>,
#  <span>Cultural Clashes in Love: How To Make Your Relationship Work</span>,
#  <span class="xhx_z">More</span>,
#  <span>10 birds that are blue in colour</span>,
#  <span>What happened to the 5 Pandavas and Draupadi after the Mahabharata war</span>,
#  <span>Elon Musk</span>,
#  <span>Creatine Benefits</span>,
#  <span>Sanya Malhotra</span>,
#  <span>Mahashivratri 2025</span>,
#  <span>Bhagwad Gita Lessons</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">NRI</span>,
#  <span>'India belongs to England': UK man racially abuses Indian-origin woman on train; see video</span>,
#  <span>Indian-origin man sentenced for killing 2 teens in New York crash</span>,
#  <span>Now, Australia cracks down on Indian students breaking rules on work</span>,
#  <span>Elon Musk's DOGE member who wanted to 'normalize Indian hate' resigns after racist posts resurface</span>,
#  <span>'Saw one die, another drown': Indians deported from US recall ‘donkey’ route ordeal</span>,
#  <span>Singapore: Indian-origin opposition leader found guilty of giving false testimony</span>,
#  <span>Worried about your immigration status? Get advice from experts in US immigration laws</span>,
#  <span>Sikh advocacy group in US working to ensure due legal process for asylum seekers from India</span>,
#  <span>Sikh leader Sukhi Chahal congratulates Tulsi Gabbard on US Senate confirmation as director of national intelligence</span>,
#  <span class="Tsj9M"></span>,
#  <span class="xhx_z">Tech</span>,
#  <span>Garena Free Fire Max Codes</span>,
#  <span>Wordle Today</span>,
#  <span>NYT Strands</span>,
#  <span>NYT Connections</span>,
#  <span>Mini Crossword</span>,
#  <span></span>,
#  <span></span>,
#  <span></span>,
#  <span></span>,
#  <span></span>,
#  <span></span>,
#  <span></span>]

# %%
for tag in desc_1 + desc_2 + desc_3:
    descriptions.append(tag.text)
descriptions
# Out:
# ["Chhaava’s excellence lies in its terrific climax. You just wish the film relied and trusted its solid story more than Rahman's music, which largely feels out of place.",
#  'Dhoom Dhaam is a fast-paced rollercoaster of action, comedy, and mystery, powered by Yami Gautam Dhar and Pratik Gandhi’s electric chemistry.',
#  'Despite its convoluted plot and occasional pacing issues, Brave New World delivers thrilling aerial battles and hand-to-hand combats, strong performances, and enough spectacle to entertain superhero',
#  '10 quotes to inspire and motivate you',
#  '10 health benefits of chewing cloves daily',
#  '10 things parents should never do in the morning before sending kids to school',
#  '10 powerful ways to detox and reset your mind',
#  '10 birds that eat meat and other animals',
#  "10 exotic animals to spot inside Kashmir's Dachigam National Park",
#  'How to make South Indian Paneer Butter Masala Dosa for breakfast',
#  '\u200b10 ancient animals that still exist',
#  'A decade ago, he was dragged out — now, Vijender Gupta will run the show as Delhi House speaker',
#  "After Trump's Indian polls expose, BJP shares old clips of PM blaming Cong",
#  'Pride of India, Asia’s first vertical-lift sea bridge set to open in TN',
#  'Will work towards mission of Viksit Delhi, says CM Rekha Gupta',
#  "'Not safe in our country': Deportees from US cry for help from Panama hotel",
#  'Everest snow cover has retreated by 490ft in 1.5 months, says study',
#  'Champions Trophy: 50-over cricket’s midlife crisis, with India twist',
#  'IND vs BAN Live: Hridoy-Jaker stand frustrate India in Dubai',
#  'Tesla likely to import cars from Germany, skip China',
#  "Watch: How Rohit Sharma messed up Axar's hat-trick chance",
#  "'Dragged out of lift, assaulted': Woman attacks minor over pet dog objection",
#  'Gurgaon lawyer held for Noida boy’s death in celebratory firing',
#  'Police receive email threat to bomb Maharashtra deputy CM Shinde’s car',
#  "'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row",
#  "California judge shoots wife during argument while watching 'Breaking Bad'",
#  'Shopping: Discounts Up to 60% Off on Gadgets & Electronics',
#  'NASA leadership changes spark uncertainty over the future of the US Moon program',
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  'Love & Dating Horoscope for February 20, 2025',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles',
#  'Horoscope Tomorrow, February 21, 2025: Your zodiac insights await',
#  'Australian children bypass social media age limit restriction as landmark ban nears: Report',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City',
#  "Trump Doubles Down On 'False' Condom Claim; '$100 Million Designated By US To Buy...'",
#  "Argentina Court Slams Liam Payne's Family, Acquits Roger Nores On 'These' Grounds | WATCH",
#  'Liam Payne Case: Argentina Court Acquits Roger Nores & 2 Hotel Employees Of All Charges',
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review",
#  'Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian Americans in entertainment sector',
#  'Horoscope Today: Astrological Predictions for February 20, 2025',
#  'If 300-ft asteroid hits earth in 2032, Mumbai and Kolkata at high risk',
#  'Trump is upending Western-led world order and India can benefit from it',
#  "Why India doesn't need ultra-pricey F-35s & what it should get instead",
#  'Bhumi recalls falling on stage in UP in front of 30,000 people',
#  'Ministry of I&B issues an advisory to OTT platforms',
#  'Arjun REACTS to people judging him for surname-looks',
#  'Bollywood Actors Who Love Painting',
#  'Celebrity MasterChef: Net worth of the contestants',
#  "Dia Mirza's ethnic wear",
#  "Sonakshi-Zaheer's adorable pics",
#  "Amyra Dastur's golden glamour",
#  "Tamannaah's animal print outfit",
#  "Madhuri's white Patola saree",
#  'Sanya redefines power dressing',
#  'B-Town divas welcome Bappa in style',
#  'Urmila Matondkar the timeless beauty',
#  "Ananya Panday's style file",
#  "Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?",
#  "Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?",
#  'Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage & Over-the-Top Acting',
#  'Exclusive: Saba Azad & Saqib Saleem Address Importance Of Self-Censorship & Side Effects Of Social Media',
#  'Blake Lively Accuses Justin Baldoni of On-Set Misconduct – Shocking Allegations Surface!',
#  'Supreme Court Hits Ranveer For ‘Perverted’ Remarks; Passport Seized, Travel Blocked - Calls Out His ‘Dirty Mind’',
#  'Heartbreaking Goodbye: Kim Sae-Ron’s Emotional Funeral Leaves K-Stars in Tears',
#  'Man locks ill mother at home, takes wife, kids to Maha Kumbh for holy dip',
#  "'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India",
#  "'Disturbing': SC on Lokpal order which entertained complaints against sitting HC judges",
#  'Ramdev blocks Bryan Johnson on X over Haridwar air quality comment on Patanjali post',
#  "‘Nahi nahi’: Delhi CM-designate Rekha Gupta on staying in 'Sheesh Mahal'",
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review",
#  'Hungary Against Ukraine’s EU Bid; Orban Says ‘Entry Will Burden Members’ | Details',
#  '‘Trump Speaks For Himself’: Senate Majority Leader Comes In Support Of Zelensky',
#  "Barbie Hsu's Ex Husband Wang Xiaofei Sparks Outrage With Contrasting Actions In China",
#  'Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage & Over-the-Top Acting',
#  'Gurgaon lawyer held for Noida boy’s death in celebratory firing',
#  'IND vs BAN Live: Shami breaks Towhid -Jaker stand',
#  "Champions Trophy: India's predicted XI vs Bangladesh | What Rohit Sharma said in the press",
#  "Mohammad Amir Exclusive: Champions Trophy hopes, India's absence & retirement talk",
#  'MS Dhoni shares his secrets for a stress-free existence',
#  "England hope 'Bazball' fires in Champions Trophy",
#  "Watch: How Rohit Sharma messed up Axar's hat-trick chance",
#  "Had doubts if I'd ever play for India again: Mohammed Shami",
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Police nab ATM scammer with Rs. 17.9 Lakh; find out where the money went',
#  "Teen dies after self-injecting butterfly remains; here's what happened",
#  "IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed",
#  '\u200b11 mysteries on the Earth that remain unsolved\u200b',
#  'Who is Elon Musk? Why is he so much in the news suddenly',
#  'The Worst Planet for a Vacation – Where Even Travel Insurance Won’t Help',
#  'From swipes to soulmates: 5 Zodiac signs that shine in online dating',
#  'If Planets Were Yoga Instructors, Who Would Be the Most Annoying?',
#  'Horoscope Today: Astrological Predictions for February 20, 2025',
#  '5 Zodiac Sign Men Who Bring Unmatched Luck to Their Wives',
#  "'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot",
#  'India auto component industry revenues to expand 8-10% in 2025-26: ICRA',
#  'iPhone parts maker Murata eyes India base',
#  'ICAI: Disciplinary action against 241 CAs, a new record',
#  'EV policy: Companies require Rs 2,500 crore sales in 2nd year',
#  'High frequency indicators point to economic recovery: RBI',
#  "This protein-packed Indian egg dish is among world's '50 best egg dishes'",
#  'How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh',
#  'How to make South Indian Appe with dosa batter for breakfast',
#  '10 protein-packed comforting dishes made with chickpeas',
#  '\u200b3 effortless ways to set restaurant-style curd\u200b',
#  'How to make Dhaba-style Champaran Chicken Handi at home',
#  "Jaya Bachchan's regal Ajrakh ensemble",
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  '10 best quotes on relationships by Sudha Murty',
#  "This protein-packed Indian egg dish is among world's '50 best egg dishes'",
#  'How to use Honey for instant hair growth',
#  '6 types of people every child will face in life and how to deal with them',
#  '8 most important lessons to take from the Bhagwad Gita',
#  '5 natural sources of Biotin which encourage hair growth',
#  'How to grow Cherry tomatoes in the balcony in under 90 days',
#  "5 designer essential bags every 'Momager' should have",
#  '10 things parents should never do in the morning before sending kids to school',
#  "10 timeless lines from Mirza Ghalib's shayaris",
#  '7 fruits that help a person lose extra fat near the belly',
#  '6 benefits of drinking ginger-turmeric tea in the morning',
#  'Sanya Malhotra approved trendy blouse designs',
#  'UK Hindus protest Islamophobia panel, say tackle all hatred',
#  'Edition',
#  'US',
#  'Sign In',
#  'Sign In',
#  '',
#  '',
#  '',
#  'In the News',
#  '',
#  'Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government',
#  'MS Dhoni shares his secrets for a stress-free existence',
#  'Are dating apps the new job portals? Woman uses Hinge for job search and shares viral chat screenshots',
#  "IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed",
#  "'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot",
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!',
#  'Champions Trophy: South Africa aim to shed chokers tag against Afghanistan',
#  'Are expecting mothers in India at risk of Vitamin D deficiency during winter?',
#  'Egg vs Paneer: Which one is a better source of protein for weight loss',
#  'Trending News',
#  '',
#  '',
#  'Entertainment',
#  "Shenaz loses a brand following Ranveer's controversy",
#  'When Ranbir left Rashmika crying on sets of Animal',
#  "Aadar calls past relationships 'time pass', faces backlash",
#  'What’s happening with the OTT deal for Sky Force?',
#  "Nicole Kidman's 'Babygirl' CENSORED in India",
#  'Vicky’s climax look in Chhaava took over four hours of make-up',
#  '6 benefits of drinking Okra water with lemon every morning',
#  'Optical illusion: What you see shows how you handle stress',
#  "Zahan Kapoor says shooting with Shah Rukh Khan was 'difficult'",
#  "Exclusive: Rozlyn shares PET scan reports with Hina's name on it",
#  'Munmun shares a hilarious video dancing to Govinda’s song',
#  "MasterChef: Farah, Ranveer and Vikas praise Gaurav's Dish",
#  "Kaveri Kapur: 'I was happy when my parents got divorced'",
#  'Vishal slams outrage over Samay and Ranveer controversy',
#  'Etimes Photos',
#  'Reviews',
#  'Critic Rating',
#  '3.5',
#  'Critic Rating',
#  '3.5',
#  'Critic Rating',
#  '3.0',
#  'In focus',
#  'Videos',
#  '',
#  'India',
#  'Who are the 6 cabinet ministers sworn in with Rekha Gupta in Delhi?',
#  'Rekha Gupta takes oath as Delhi CM in presence of PM Modi, top NDA leaders',
#  'Tribunals can’t overturn its own finding on Assam foreigners: SC',
#  'SC adjourns hearing on challenge to CEC, EC selection law; hearings on pre-fixed cases consume bench’s judicial schedule',
#  "'Arvind Kejriwal will have to spend most of his time in jail': BJP's Delhi minister-pick Manjinder Singh Sirsa",
#  "Trump admits to poll interference in India, BJP shares PM's clips to pin blame on Congress",
#  'UP Budget 2025 is dedicated to Sanatan culture of India: Yogi Adityanath',
#  "'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row",
#  'In pics: Meet the newly sworn-in cabinet of Delhi assembly',
#  'TOI Videos',
#  '',
#  'City',
#  "In picking Rekha Gupta for Delhi CM's post, RSS student wing strikes again",
#  "HC seeks Uttarakhand govt's reply as UCC form asks for live-in couples’ past info",
#  'As oven deadline looms, Maharashtra neta seeks heritage tag for Irani bakeries',
#  "Youth who entered Shah Rukh Khan's bungalow 'Mannat' in 2023 caught for burglary in Gujarat",
#  "Delhi CM's oath-taking today; BJP pulls out all stops to make it a grand affair",
#  'Wife, ‘lover’ held for killing man pursuing her rape case in UP court',
#  'Uttarakhand to ban outsiders from buying agri land',
#  'Planned drama, says Muda scam case petitioner as Lokayukta gives Siddaramaiah, his wife clean chit',
#  'Arvind Kejriwal, Atishi among those to congratulate Delhi CM-designate Rekha Gupta',
#  '',
#  'Sports',
#  "ICC approves Imam-ul-Haq as Fakhar's replacement in Pak squad",
#  "'Thoda aur bhaiya' - Samson's cute reaction to Dhoni's IPL career",
#  'Dominant NZ crush Pakistan in Champions Trophy opener',
#  "CT Digest: India open campaign after Pakistan's sorry start",
#  "India's spin puzzle: Why Axar, Jadeja are irreplaceable in Champions Trophy plans",
#  'Jerk Fox',
#  'Josh Allen',
#  'Patrick Mahomes',
#  'Jimmy Butler',
#  'Luka Doncic',
#  '',
#  'Trending',
#  '',
#  'Visual Stories',
#  '',
#  'Astrology',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City',
#  'Which Zodiac Would Have the Best Theme Park?',
#  'Beyond swipes: 5 Zodiac signs that crave deep, real-life love',
#  'Love & Dating Horoscope for February 20, 2025',
#  'Which Zodiac Would Have the Most Aesthetic Instagram Feed?',
#  'Best Husbands by Date of Birth – Because the Stars Have a Type',
#  'Horoscope Tomorrow, February 21, 2025: Your zodiac insights await',
#  '7 Things to Absolutely Avoid During Shivratri – Unless Chaos is the Goal',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles',
#  '',
#  'US News',
#  'Who is Leland Dudek? Pro-DOGE ‘anti-fraud expert’ takes over as SSA chief after Michelle King’s exit',
#  "'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India",
#  "California judge shoots wife during argument while watching 'Breaking Bad'",
#  "Elon Musk 'misinterprets' Social Security data; Experts say millions of dead not receiving benefits",
#  'Watch: Mississippi lieutenant governor Delbert Hosemann collapses on Senate podium while giving speech',
#  'Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government',
#  'Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian-Americans in entertainment sector',
#  'How FBI lead Kash Patel stands to make millions from Shein the Chinese company',
#  "Donald Trump wants his new Air Force One jets fast: ‘Boeing's been building this thing forever’",
#  '',
#  'Business',
#  'GenNext less focused on building companies: Uday Kotak',
#  "Automobiles on government's list for trade talks with US",
#  'Irdai forms committee to review Insurance Act',
#  'Tesla likely to import cars from Germany, skip China',
#  'Salary hikes to be flat at 9.2%: Survey',
#  'UPI users take note! Google Pay introduces convenience fee for these transactions',
#  'Why India may raise GST on cigarettes and other tobacco products',
#  'Top stocks to buy today: Stock recommendations for February 20, 2025',
#  'Stock market today: BSE Sensex opens over 300 points down; Nifty50 below 22,900',
#  'Axis Bank',
#  'Provident Fund',
#  'Income Tax Slabs',
#  'GST',
#  'Fixed Deposit rates',
#  '',
#  'Recipes',
#  '',
#  'Lifestyle',
#  'Style',
#  'Sanya Malhotra’s vintage outfit roars heritage',
#  '5 celebs who grabbed eyeballs with distressed looks',
#  'Health & Fitness',
#  'Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!',
#  'Egg vs Paneer: Which one is a better source of protein for weight loss',
#  'Relationship',
#  'Personality Test: Your foot arch reveals if you are grounded or a free spirit',
#  "Meet King Charles III's dashing bodyguard, whom royal fans compare to James Bond",
#  'Food',
#  'How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh',
#  'How to make South Indian Appe with dosa batter for breakfast',
#  'Beauty',
#  "'Mrs.' actress Sanya Malhotra's curly hair routine revealed",
#  'Can Henna or Mehendi increase hair growth?',
#  'Parenting',
#  '10 morning habits successful kids are encouraged to follow',
#  'Baby names inspired by Shreenathji',
#  'Books',
#  "10 timeless lines from Mirza Ghalib's shayaris",
#  '8 books that help magically improve relationships and love issues',
#  'Videos',
#  'Control Your Senses, Gain Knowledge, Attain Peace: Bhagavad Gita, Chapter 4.39',
#  'Cultural Clashes in Love: How To Make Your Relationship Work',
#  'More',
#  '10 birds that are blue in colour',
#  'What happened to the 5 Pandavas and Draupadi after the Mahabharata war',
#  'Elon Musk',
#  'Creatine Benefits',
#  'Sanya Malhotra',
#  'Mahashivratri 2025',
#  'Bhagwad Gita Lessons',
#  '',
#  'NRI',
#  "'India belongs to England': UK man racially abuses Indian-origin woman on train; see video",
#  'Indian-origin man sentenced for killing 2 teens in New York crash',
#  'Now, Australia cracks down on Indian students breaking rules on work',
#  "Elon Musk's DOGE member who wanted to 'normalize Indian hate' resigns after racist posts resurface",
#  "'Saw one die, another drown': Indians deported from US recall ‘donkey’ route ordeal",
#  'Singapore: Indian-origin opposition leader found guilty of giving false testimony',
#  'Worried about your immigration status? Get advice from experts in US immigration laws',
#  'Sikh advocacy group in US working to ensure due legal process for asylum seekers from India',
#  'Sikh leader Sukhi Chahal congratulates Tulsi Gabbard on US Senate confirmation as director of national intelligence',
#  '',
#  'Tech',
#  'Garena Free Fire Max Codes',
#  'Wordle Today',
#  'NYT Strands',
#  'NYT Connections',
#  'Mini Crossword',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "Chhaava’s excellence lies in its terrific climax. You just wish the film relied and trusted its solid story more than Rahman's music, which largely feels out of place.",
#  'Dhoom Dhaam is a fast-paced rollercoaster of action, comedy, and mystery, powered by Yami Gautam Dhar and Pratik Gandhi’s electric chemistry.',
#  'Despite its convoluted plot and occasional pacing issues, Brave New World delivers thrilling aerial battles and hand-to-hand combats, strong performances, and enough spectacle to entertain superhero',
#  '10 quotes to inspire and motivate you',
#  '10 health benefits of chewing cloves daily',
#  '10 things parents should never do in the morning before sending kids to school',
#  '10 powerful ways to detox and reset your mind',
#  '10 birds that eat meat and other animals',
#  "10 exotic animals to spot inside Kashmir's Dachigam National Park",
#  'How to make South Indian Paneer Butter Masala Dosa for breakfast',
#  '\u200b10 ancient animals that still exist',
#  'A decade ago, he was dragged out — now, Vijender Gupta will run the show as Delhi House speaker',
#  "After Trump's Indian polls expose, BJP shares old clips of PM blaming Cong",
#  'Pride of India, Asia’s first vertical-lift sea bridge set to open in TN',
#  'Will work towards mission of Viksit Delhi, says CM Rekha Gupta',
#  "'Not safe in our country': Deportees from US cry for help from Panama hotel",
#  'Everest snow cover has retreated by 490ft in 1.5 months, says study',
#  'Champions Trophy: 50-over cricket’s midlife crisis, with India twist',
#  'IND vs BAN Live: Hridoy-Jaker stand frustrate India in Dubai',
#  'Tesla likely to import cars from Germany, skip China',
#  "Watch: How Rohit Sharma messed up Axar's hat-trick chance",
#  "'Dragged out of lift, assaulted': Woman attacks minor over pet dog objection",
#  'Gurgaon lawyer held for Noida boy’s death in celebratory firing',
#  'Police receive email threat to bomb Maharashtra deputy CM Shinde’s car',
#  "'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row",
#  "California judge shoots wife during argument while watching 'Breaking Bad'",
#  'Shopping: Discounts Up to 60% Off on Gadgets & Electronics',
#  'NASA leadership changes spark uncertainty over the future of the US Moon program',
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  'Love & Dating Horoscope for February 20, 2025',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles',
#  'Horoscope Tomorrow, February 21, 2025: Your zodiac insights await',
#  'Australian children bypass social media age limit restriction as landmark ban nears: Report',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City',
#  "Trump Doubles Down On 'False' Condom Claim; '$100 Million Designated By US To Buy...'",
#  "Argentina Court Slams Liam Payne's Family, Acquits Roger Nores On 'These' Grounds | WATCH",
#  'Liam Payne Case: Argentina Court Acquits Roger Nores & 2 Hotel Employees Of All Charges',
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review",
#  'Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian Americans in entertainment sector',
#  'Horoscope Today: Astrological Predictions for February 20, 2025',
#  'If 300-ft asteroid hits earth in 2032, Mumbai and Kolkata at high risk',
#  'Trump is upending Western-led world order and India can benefit from it',
#  "Why India doesn't need ultra-pricey F-35s & what it should get instead",
#  'Bhumi recalls falling on stage in UP in front of 30,000 people',
#  'Ministry of I&B issues an advisory to OTT platforms',
#  'Arjun REACTS to people judging him for surname-looks',
#  'Bollywood Actors Who Love Painting',
#  'Celebrity MasterChef: Net worth of the contestants',
#  "Dia Mirza's ethnic wear",
#  "Sonakshi-Zaheer's adorable pics",
#  "Amyra Dastur's golden glamour",
#  "Tamannaah's animal print outfit",
#  "Madhuri's white Patola saree",
#  'Sanya redefines power dressing',
#  'B-Town divas welcome Bappa in style',
#  'Urmila Matondkar the timeless beauty',
#  "Ananya Panday's style file",
#  "Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?",
#  "Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?",
#  'Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage & Over-the-Top Acting',
#  'Exclusive: Saba Azad & Saqib Saleem Address Importance Of Self-Censorship & Side Effects Of Social Media',
#  'Blake Lively Accuses Justin Baldoni of On-Set Misconduct – Shocking Allegations Surface!',
#  'Supreme Court Hits Ranveer For ‘Perverted’ Remarks; Passport Seized, Travel Blocked - Calls Out His ‘Dirty Mind’',
#  'Heartbreaking Goodbye: Kim Sae-Ron’s Emotional Funeral Leaves K-Stars in Tears',
#  'Man locks ill mother at home, takes wife, kids to Maha Kumbh for holy dip',
#  "'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India",
#  "'Disturbing': SC on Lokpal order which entertained complaints against sitting HC judges",
#  'Ramdev blocks Bryan Johnson on X over Haridwar air quality comment on Patanjali post',
#  "‘Nahi nahi’: Delhi CM-designate Rekha Gupta on staying in 'Sheesh Mahal'",
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review",
#  'Hungary Against Ukraine’s EU Bid; Orban Says ‘Entry Will Burden Members’ | Details',
#  '‘Trump Speaks For Himself’: Senate Majority Leader Comes In Support Of Zelensky',
#  "Barbie Hsu's Ex Husband Wang Xiaofei Sparks Outrage With Contrasting Actions In China",
#  'Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage & Over-the-Top Acting',
#  'Gurgaon lawyer held for Noida boy’s death in celebratory firing',
#  'IND vs BAN Live: Shami breaks Towhid -Jaker stand',
#  "Champions Trophy: India's predicted XI vs Bangladesh | What Rohit Sharma said in the press",
#  "Mohammad Amir Exclusive: Champions Trophy hopes, India's absence & retirement talk",
#  'MS Dhoni shares his secrets for a stress-free existence',
#  "England hope 'Bazball' fires in Champions Trophy",
#  "Watch: How Rohit Sharma messed up Axar's hat-trick chance",
#  "Had doubts if I'd ever play for India again: Mohammed Shami",
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Police nab ATM scammer with Rs. 17.9 Lakh; find out where the money went',
#  "Teen dies after self-injecting butterfly remains; here's what happened",
#  "IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed",
#  '\u200b11 mysteries on the Earth that remain unsolved\u200b',
#  'Who is Elon Musk? Why is he so much in the news suddenly',
#  'The Worst Planet for a Vacation – Where Even Travel Insurance Won’t Help',
#  'From swipes to soulmates: 5 Zodiac signs that shine in online dating',
#  'If Planets Were Yoga Instructors, Who Would Be the Most Annoying?',
#  'Horoscope Today: Astrological Predictions for February 20, 2025',
#  '5 Zodiac Sign Men Who Bring Unmatched Luck to Their Wives',
#  "'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot",
#  'India auto component industry revenues to expand 8-10% in 2025-26: ICRA',
#  'iPhone parts maker Murata eyes India base',
#  'ICAI: Disciplinary action against 241 CAs, a new record',
#  'EV policy: Companies require Rs 2,500 crore sales in 2nd year',
#  'High frequency indicators point to economic recovery: RBI',
#  "This protein-packed Indian egg dish is among world's '50 best egg dishes'",
#  'How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh',
#  'How to make South Indian Appe with dosa batter for breakfast',
#  '10 protein-packed comforting dishes made with chickpeas',
#  '\u200b3 effortless ways to set restaurant-style curd\u200b',
#  'How to make Dhaba-style Champaran Chicken Handi at home',
#  "Jaya Bachchan's regal Ajrakh ensemble",
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  '10 best quotes on relationships by Sudha Murty',
#  "This protein-packed Indian egg dish is among world's '50 best egg dishes'",
#  'How to use Honey for instant hair growth',
#  '6 types of people every child will face in life and how to deal with them',
#  '8 most important lessons to take from the Bhagwad Gita',
#  '5 natural sources of Biotin which encourage hair growth',
#  'How to grow Cherry tomatoes in the balcony in under 90 days',
#  "5 designer essential bags every 'Momager' should have",
#  '10 things parents should never do in the morning before sending kids to school',
#  "10 timeless lines from Mirza Ghalib's shayaris",
#  '7 fruits that help a person lose extra fat near the belly',
#  '6 benefits of drinking ginger-turmeric tea in the morning',
#  'Sanya Malhotra approved trendy blouse designs',
#  'UK Hindus protest Islamophobia panel, say tackle all hatred',
#  'Edition',
#  'US',
#  'Sign In',
#  'Sign In',
#  '',
#  '',
#  '',
#  'In the News',
#  '',
#  'Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government',
#  'MS Dhoni shares his secrets for a stress-free existence',
#  'Are dating apps the new job portals? Woman uses Hinge for job search and shares viral chat screenshots',
#  "IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed",
#  "'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot",
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!',
#  'Champions Trophy: South Africa aim to shed chokers tag against Afghanistan',
#  'Are expecting mothers in India at risk of Vitamin D deficiency during winter?',
#  'Egg vs Paneer: Which one is a better source of protein for weight loss',
#  'Trending News',
#  '',
#  '',
#  'Entertainment',
#  "Shenaz loses a brand following Ranveer's controversy",
#  'When Ranbir left Rashmika crying on sets of Animal',
#  "Aadar calls past relationships 'time pass', faces backlash",
#  'What’s happening with the OTT deal for Sky Force?',
#  "Nicole Kidman's 'Babygirl' CENSORED in India",
#  'Vicky’s climax look in Chhaava took over four hours of make-up',
#  '6 benefits of drinking Okra water with lemon every morning',
#  'Optical illusion: What you see shows how you handle stress',
#  "Zahan Kapoor says shooting with Shah Rukh Khan was 'difficult'",
#  "Exclusive: Rozlyn shares PET scan reports with Hina's name on it",
#  'Munmun shares a hilarious video dancing to Govinda’s song',
#  "MasterChef: Farah, Ranveer and Vikas praise Gaurav's Dish",
#  "Kaveri Kapur: 'I was happy when my parents got divorced'",
#  'Vishal slams outrage over Samay and Ranveer controversy',
#  'Etimes Photos',
#  'Reviews',
#  'Critic Rating',
#  '3.5',
#  'Critic Rating',
#  '3.5',
#  'Critic Rating',
#  '3.0',
#  'In focus',
#  'Videos',
#  '',
#  'India',
#  'Who are the 6 cabinet ministers sworn in with Rekha Gupta in Delhi?',
#  'Rekha Gupta takes oath as Delhi CM in presence of PM Modi, top NDA leaders',
#  'Tribunals can’t overturn its own finding on Assam foreigners: SC',
#  'SC adjourns hearing on challenge to CEC, EC selection law; hearings on pre-fixed cases consume bench’s judicial schedule',
#  "'Arvind Kejriwal will have to spend most of his time in jail': BJP's Delhi minister-pick Manjinder Singh Sirsa",
#  "Trump admits to poll interference in India, BJP shares PM's clips to pin blame on Congress",
#  'UP Budget 2025 is dedicated to Sanatan culture of India: Yogi Adityanath',
#  "'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row",
#  'In pics: Meet the newly sworn-in cabinet of Delhi assembly',
#  'TOI Videos',
#  '',
#  'City',
#  "In picking Rekha Gupta for Delhi CM's post, RSS student wing strikes again",
#  "HC seeks Uttarakhand govt's reply as UCC form asks for live-in couples’ past info",
#  'As oven deadline looms, Maharashtra neta seeks heritage tag for Irani bakeries',
#  "Youth who entered Shah Rukh Khan's bungalow 'Mannat' in 2023 caught for burglary in Gujarat",
#  "Delhi CM's oath-taking today; BJP pulls out all stops to make it a grand affair",
#  'Wife, ‘lover’ held for killing man pursuing her rape case in UP court',
#  'Uttarakhand to ban outsiders from buying agri land',
#  'Planned drama, says Muda scam case petitioner as Lokayukta gives Siddaramaiah, his wife clean chit',
#  'Arvind Kejriwal, Atishi among those to congratulate Delhi CM-designate Rekha Gupta',
#  '',
#  'Sports',
#  "ICC approves Imam-ul-Haq as Fakhar's replacement in Pak squad",
#  "'Thoda aur bhaiya' - Samson's cute reaction to Dhoni's IPL career",
#  'Dominant NZ crush Pakistan in Champions Trophy opener',
#  "CT Digest: India open campaign after Pakistan's sorry start",
#  "India's spin puzzle: Why Axar, Jadeja are irreplaceable in Champions Trophy plans",
#  'Jerk Fox',
#  'Josh Allen',
#  'Patrick Mahomes',
#  'Jimmy Butler',
#  'Luka Doncic',
#  '',
#  'Trending',
#  '',
#  'Visual Stories',
#  '',
#  'Astrology',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City',
#  'Which Zodiac Would Have the Best Theme Park?',
#  'Beyond swipes: 5 Zodiac signs that crave deep, real-life love',
#  'Love & Dating Horoscope for February 20, 2025',
#  'Which Zodiac Would Have the Most Aesthetic Instagram Feed?',
#  'Best Husbands by Date of Birth – Because the Stars Have a Type',
#  'Horoscope Tomorrow, February 21, 2025: Your zodiac insights await',
#  '7 Things to Absolutely Avoid During Shivratri – Unless Chaos is the Goal',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles',
#  '',
#  'US News',
#  'Who is Leland Dudek? Pro-DOGE ‘anti-fraud expert’ takes over as SSA chief after Michelle King’s exit',
#  "'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India",
#  "California judge shoots wife during argument while watching 'Breaking Bad'",
#  "Elon Musk 'misinterprets' Social Security data; Experts say millions of dead not receiving benefits",
#  'Watch: Mississippi lieutenant governor Delbert Hosemann collapses on Senate podium while giving speech',
#  'Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government',
#  'Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian-Americans in entertainment sector',
#  'How FBI lead Kash Patel stands to make millions from Shein the Chinese company',
#  "Donald Trump wants his new Air Force One jets fast: ‘Boeing's been building this thing forever’",
#  '',
#  'Business',
#  'GenNext less focused on building companies: Uday Kotak',
#  "Automobiles on government's list for trade talks with US",
#  'Irdai forms committee to review Insurance Act',
#  'Tesla likely to import cars from Germany, skip China',
#  'Salary hikes to be flat at 9.2%: Survey',
#  'UPI users take note! Google Pay introduces convenience fee for these transactions',
#  'Why India may raise GST on cigarettes and other tobacco products',
#  'Top stocks to buy today: Stock recommendations for February 20, 2025',
#  'Stock market today: BSE Sensex opens over 300 points down; Nifty50 below 22,900',
#  'Axis Bank',
#  'Provident Fund',
#  'Income Tax Slabs',
#  'GST',
#  'Fixed Deposit rates',
#  '',
#  'Recipes',
#  '',
#  'Lifestyle',
#  'Style',
#  'Sanya Malhotra’s vintage outfit roars heritage',
#  '5 celebs who grabbed eyeballs with distressed looks',
#  'Health & Fitness',
#  'Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!',
#  'Egg vs Paneer: Which one is a better source of protein for weight loss',
#  'Relationship',
#  'Personality Test: Your foot arch reveals if you are grounded or a free spirit',
#  "Meet King Charles III's dashing bodyguard, whom royal fans compare to James Bond",
#  'Food',
#  'How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh',
#  'How to make South Indian Appe with dosa batter for breakfast',
#  'Beauty',
#  "'Mrs.' actress Sanya Malhotra's curly hair routine revealed",
#  'Can Henna or Mehendi increase hair growth?',
#  'Parenting',
#  '10 morning habits successful kids are encouraged to follow',
#  'Baby names inspired by Shreenathji',
#  'Books',
#  "10 timeless lines from Mirza Ghalib's shayaris",
#  '8 books that help magically improve relationships and love issues',
#  'Videos',
#  'Control Your Senses, Gain Knowledge, Attain Peace: Bhagavad Gita, Chapter 4.39',
#  'Cultural Clashes in Love: How To Make Your Relationship Work',
#  'More',
#  '10 birds that are blue in colour',
#  'What happened to the 5 Pandavas and Draupadi after the Mahabharata war',
#  'Elon Musk',
#  'Creatine Benefits',
#  'Sanya Malhotra',
#  'Mahashivratri 2025',
#  'Bhagwad Gita Lessons',
#  '',
#  'NRI',
#  "'India belongs to England': UK man racially abuses Indian-origin woman on train; see video",
#  'Indian-origin man sentenced for killing 2 teens in New York crash',
#  'Now, Australia cracks down on Indian students breaking rules on work',
#  "Elon Musk's DOGE member who wanted to 'normalize Indian hate' resigns after racist posts resurface",
#  "'Saw one die, another drown': Indians deported from US recall ‘donkey’ route ordeal",
#  'Singapore: Indian-origin opposition leader found guilty of giving false testimony',
#  'Worried about your immigration status? Get advice from experts in US immigration laws',
#  'Sikh advocacy group in US working to ensure due legal process for asylum seekers from India',
#  'Sikh leader Sukhi Chahal congratulates Tulsi Gabbard on US Senate confirmation as director of national intelligence',
#  '',
#  'Tech',
#  'Garena Free Fire Max Codes',
#  'Wordle Today',
#  'NYT Strands',
#  'NYT Connections',
#  'Mini Crossword',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "Chhaava’s excellence lies in its terrific climax. You just wish the film relied and trusted its solid story more than Rahman's music, which largely feels out of place.",
#  'Dhoom Dhaam is a fast-paced rollercoaster of action, comedy, and mystery, powered by Yami Gautam Dhar and Pratik Gandhi’s electric chemistry.',
#  'Despite its convoluted plot and occasional pacing issues, Brave New World delivers thrilling aerial battles and hand-to-hand combats, strong performances, and enough spectacle to entertain superhero',
#  '10 quotes to inspire and motivate you',
#  '10 health benefits of chewing cloves daily',
#  '10 things parents should never do in the morning before sending kids to school',
#  '10 powerful ways to detox and reset your mind',
#  '10 birds that eat meat and other animals',
#  "10 exotic animals to spot inside Kashmir's Dachigam National Park",
#  'How to make South Indian Paneer Butter Masala Dosa for breakfast',
#  '\u200b10 ancient animals that still exist',
#  'A decade ago, he was dragged out — now, Vijender Gupta will run the show as Delhi House speaker',
#  "After Trump's Indian polls expose, BJP shares old clips of PM blaming Cong",
#  'Pride of India, Asia’s first vertical-lift sea bridge set to open in TN',
#  'Will work towards mission of Viksit Delhi, says CM Rekha Gupta',
#  "'Not safe in our country': Deportees from US cry for help from Panama hotel",
#  'Everest snow cover has retreated by 490ft in 1.5 months, says study',
#  'Champions Trophy: 50-over cricket’s midlife crisis, with India twist',
#  'IND vs BAN Live: Hridoy-Jaker stand frustrate India in Dubai',
#  'Tesla likely to import cars from Germany, skip China',
#  "Watch: How Rohit Sharma messed up Axar's hat-trick chance",
#  "'Dragged out of lift, assaulted': Woman attacks minor over pet dog objection",
#  'Gurgaon lawyer held for Noida boy’s death in celebratory firing',
#  'Police receive email threat to bomb Maharashtra deputy CM Shinde’s car',
#  "'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row",
#  "California judge shoots wife during argument while watching 'Breaking Bad'",
#  'Shopping: Discounts Up to 60% Off on Gadgets & Electronics',
#  'NASA leadership changes spark uncertainty over the future of the US Moon program',
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  'Love & Dating Horoscope for February 20, 2025',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles',
#  'Horoscope Tomorrow, February 21, 2025: Your zodiac insights await',
#  'Australian children bypass social media age limit restriction as landmark ban nears: Report',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City',
#  "Trump Doubles Down On 'False' Condom Claim; '$100 Million Designated By US To Buy...'",
#  "Argentina Court Slams Liam Payne's Family, Acquits Roger Nores On 'These' Grounds | WATCH",
#  'Liam Payne Case: Argentina Court Acquits Roger Nores & 2 Hotel Employees Of All Charges',
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review",
#  'Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian Americans in entertainment sector',
#  'Horoscope Today: Astrological Predictions for February 20, 2025',
#  'If 300-ft asteroid hits earth in 2032, Mumbai and Kolkata at high risk',
#  'Trump is upending Western-led world order and India can benefit from it',
#  "Why India doesn't need ultra-pricey F-35s & what it should get instead",
#  'Bhumi recalls falling on stage in UP in front of 30,000 people',
#  'Ministry of I&B issues an advisory to OTT platforms',
#  'Arjun REACTS to people judging him for surname-looks',
#  'Bollywood Actors Who Love Painting',
#  'Celebrity MasterChef: Net worth of the contestants',
#  "Dia Mirza's ethnic wear",
#  "Sonakshi-Zaheer's adorable pics",
#  "Amyra Dastur's golden glamour",
#  "Tamannaah's animal print outfit",
#  "Madhuri's white Patola saree",
#  'Sanya redefines power dressing',
#  'B-Town divas welcome Bappa in style',
#  'Urmila Matondkar the timeless beauty',
#  "Ananya Panday's style file",
#  "Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?",
#  "Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?",
#  'Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage & Over-the-Top Acting',
#  'Exclusive: Saba Azad & Saqib Saleem Address Importance Of Self-Censorship & Side Effects Of Social Media',
#  'Blake Lively Accuses Justin Baldoni of On-Set Misconduct – Shocking Allegations Surface!',
#  'Supreme Court Hits Ranveer For ‘Perverted’ Remarks; Passport Seized, Travel Blocked - Calls Out His ‘Dirty Mind’',
#  'Heartbreaking Goodbye: Kim Sae-Ron’s Emotional Funeral Leaves K-Stars in Tears',
#  'Man locks ill mother at home, takes wife, kids to Maha Kumbh for holy dip',
#  "'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India",
#  "'Disturbing': SC on Lokpal order which entertained complaints against sitting HC judges",
#  'Ramdev blocks Bryan Johnson on X over Haridwar air quality comment on Patanjali post',
#  "‘Nahi nahi’: Delhi CM-designate Rekha Gupta on staying in 'Sheesh Mahal'",
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review",
#  'Hungary Against Ukraine’s EU Bid; Orban Says ‘Entry Will Burden Members’ | Details',
#  '‘Trump Speaks For Himself’: Senate Majority Leader Comes In Support Of Zelensky',
#  "Barbie Hsu's Ex Husband Wang Xiaofei Sparks Outrage With Contrasting Actions In China",
#  'Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage & Over-the-Top Acting',
#  'Gurgaon lawyer held for Noida boy’s death in celebratory firing',
#  'IND vs BAN Live: Shami breaks Towhid -Jaker stand',
#  "Champions Trophy: India's predicted XI vs Bangladesh | What Rohit Sharma said in the press",
#  "Mohammad Amir Exclusive: Champions Trophy hopes, India's absence & retirement talk",
#  'MS Dhoni shares his secrets for a stress-free existence',
#  "England hope 'Bazball' fires in Champions Trophy",
#  "Watch: How Rohit Sharma messed up Axar's hat-trick chance",
#  "Had doubts if I'd ever play for India again: Mohammed Shami",
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Police nab ATM scammer with Rs. 17.9 Lakh; find out where the money went',
#  "Teen dies after self-injecting butterfly remains; here's what happened",
#  "IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed",
#  '\u200b11 mysteries on the Earth that remain unsolved\u200b',
#  'Who is Elon Musk? Why is he so much in the news suddenly',
#  'The Worst Planet for a Vacation – Where Even Travel Insurance Won’t Help',
#  'From swipes to soulmates: 5 Zodiac signs that shine in online dating',
#  'If Planets Were Yoga Instructors, Who Would Be the Most Annoying?',
#  'Horoscope Today: Astrological Predictions for February 20, 2025',
#  '5 Zodiac Sign Men Who Bring Unmatched Luck to Their Wives',
#  "'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot",
#  'India auto component industry revenues to expand 8-10% in 2025-26: ICRA',
#  'iPhone parts maker Murata eyes India base',
#  'ICAI: Disciplinary action against 241 CAs, a new record',
#  'EV policy: Companies require Rs 2,500 crore sales in 2nd year',
#  'High frequency indicators point to economic recovery: RBI',
#  "This protein-packed Indian egg dish is among world's '50 best egg dishes'",
#  'How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh',
#  'How to make South Indian Appe with dosa batter for breakfast',
#  '10 protein-packed comforting dishes made with chickpeas',
#  '\u200b3 effortless ways to set restaurant-style curd\u200b',
#  'How to make Dhaba-style Champaran Chicken Handi at home',
#  "Jaya Bachchan's regal Ajrakh ensemble",
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  '10 best quotes on relationships by Sudha Murty',
#  "This protein-packed Indian egg dish is among world's '50 best egg dishes'",
#  'How to use Honey for instant hair growth',
#  '6 types of people every child will face in life and how to deal with them',
#  '8 most important lessons to take from the Bhagwad Gita',
#  '5 natural sources of Biotin which encourage hair growth',
#  'How to grow Cherry tomatoes in the balcony in under 90 days',
#  "5 designer essential bags every 'Momager' should have",
#  '10 things parents should never do in the morning before sending kids to school',
#  "10 timeless lines from Mirza Ghalib's shayaris",
#  '7 fruits that help a person lose extra fat near the belly',
#  '6 benefits of drinking ginger-turmeric tea in the morning',
#  'Sanya Malhotra approved trendy blouse designs',
#  'UK Hindus protest Islamophobia panel, say tackle all hatred',
#  'Edition',
#  'US',
#  'Sign In',
#  'Sign In',
#  '',
#  '',
#  '',
#  'In the News',
#  '',
#  'Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government',
#  'MS Dhoni shares his secrets for a stress-free existence',
#  'Are dating apps the new job portals? Woman uses Hinge for job search and shares viral chat screenshots',
#  "IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed",
#  "'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot",
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!',
#  'Champions Trophy: South Africa aim to shed chokers tag against Afghanistan',
#  'Are expecting mothers in India at risk of Vitamin D deficiency during winter?',
#  'Egg vs Paneer: Which one is a better source of protein for weight loss',
#  'Trending News',
#  '',
#  '',
#  'Entertainment',
#  "Shenaz loses a brand following Ranveer's controversy",
#  'When Ranbir left Rashmika crying on sets of Animal',
#  "Aadar calls past relationships 'time pass', faces backlash",
#  'What’s happening with the OTT deal for Sky Force?',
#  "Nicole Kidman's 'Babygirl' CENSORED in India",
#  'Vicky’s climax look in Chhaava took over four hours of make-up',
#  '6 benefits of drinking Okra water with lemon every morning',
#  'Optical illusion: What you see shows how you handle stress',
#  "Zahan Kapoor says shooting with Shah Rukh Khan was 'difficult'",
#  "Exclusive: Rozlyn shares PET scan reports with Hina's name on it",
#  'Munmun shares a hilarious video dancing to Govinda’s song',
#  "MasterChef: Farah, Ranveer and Vikas praise Gaurav's Dish",
#  "Kaveri Kapur: 'I was happy when my parents got divorced'",
#  'Vishal slams outrage over Samay and Ranveer controversy',
#  'Etimes Photos',
#  'Reviews',
#  'Critic Rating',
#  '3.5',
#  'Critic Rating',
#  '3.5',
#  'Critic Rating',
#  '3.0',
#  'In focus',
#  'Videos',
#  '',
#  'India',
#  'Who are the 6 cabinet ministers sworn in with Rekha Gupta in Delhi?',
#  'Rekha Gupta takes oath as Delhi CM in presence of PM Modi, top NDA leaders',
#  'Tribunals can’t overturn its own finding on Assam foreigners: SC',
#  'SC adjourns hearing on challenge to CEC, EC selection law; hearings on pre-fixed cases consume bench’s judicial schedule',
#  "'Arvind Kejriwal will have to spend most of his time in jail': BJP's Delhi minister-pick Manjinder Singh Sirsa",
#  "Trump admits to poll interference in India, BJP shares PM's clips to pin blame on Congress",
#  'UP Budget 2025 is dedicated to Sanatan culture of India: Yogi Adityanath',
#  "'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row",
#  'In pics: Meet the newly sworn-in cabinet of Delhi assembly',
#  'TOI Videos',
#  '',
#  'City',
#  "In picking Rekha Gupta for Delhi CM's post, RSS student wing strikes again",
#  "HC seeks Uttarakhand govt's reply as UCC form asks for live-in couples’ past info",
#  'As oven deadline looms, Maharashtra neta seeks heritage tag for Irani bakeries',
#  "Youth who entered Shah Rukh Khan's bungalow 'Mannat' in 2023 caught for burglary in Gujarat",
#  "Delhi CM's oath-taking today; BJP pulls out all stops to make it a grand affair",
#  'Wife, ‘lover’ held for killing man pursuing her rape case in UP court',
#  'Uttarakhand to ban outsiders from buying agri land',
#  'Planned drama, says Muda scam case petitioner as Lokayukta gives Siddaramaiah, his wife clean chit',
#  'Arvind Kejriwal, Atishi among those to congratulate Delhi CM-designate Rekha Gupta',
#  '',
#  'Sports',
#  "ICC approves Imam-ul-Haq as Fakhar's replacement in Pak squad",
#  "'Thoda aur bhaiya' - Samson's cute reaction to Dhoni's IPL career",
#  'Dominant NZ crush Pakistan in Champions Trophy opener',
#  "CT Digest: India open campaign after Pakistan's sorry start",
#  "India's spin puzzle: Why Axar, Jadeja are irreplaceable in Champions Trophy plans",
#  'Jerk Fox',
#  'Josh Allen',
#  'Patrick Mahomes',
#  'Jimmy Butler',
#  'Luka Doncic',
#  '',
#  'Trending',
#  '',
#  'Visual Stories',
#  '',
#  'Astrology',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City',
#  'Which Zodiac Would Have the Best Theme Park?',
#  'Beyond swipes: 5 Zodiac signs that crave deep, real-life love',
#  'Love & Dating Horoscope for February 20, 2025',
#  'Which Zodiac Would Have the Most Aesthetic Instagram Feed?',
#  'Best Husbands by Date of Birth – Because the Stars Have a Type',
#  'Horoscope Tomorrow, February 21, 2025: Your zodiac insights await',
#  '7 Things to Absolutely Avoid During Shivratri – Unless Chaos is the Goal',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles',
#  '',
#  'US News',
#  'Who is Leland Dudek? Pro-DOGE ‘anti-fraud expert’ takes over as SSA chief after Michelle King’s exit',
#  "'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India",
#  "California judge shoots wife during argument while watching 'Breaking Bad'",
#  "Elon Musk 'misinterprets' Social Security data; Experts say millions of dead not receiving benefits",
#  'Watch: Mississippi lieutenant governor Delbert Hosemann collapses on Senate podium while giving speech',
#  'Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government',
#  'Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian-Americans in entertainment sector',
#  'How FBI lead Kash Patel stands to make millions from Shein the Chinese company',
#  "Donald Trump wants his new Air Force One jets fast: ‘Boeing's been building this thing forever’",
#  '',
#  'Business',
#  'GenNext less focused on building companies: Uday Kotak',
#  "Automobiles on government's list for trade talks with US",
#  'Irdai forms committee to review Insurance Act',
#  'Tesla likely to import cars from Germany, skip China',
#  'Salary hikes to be flat at 9.2%: Survey',
#  'UPI users take note! Google Pay introduces convenience fee for these transactions',
#  'Why India may raise GST on cigarettes and other tobacco products',
#  'Top stocks to buy today: Stock recommendations for February 20, 2025',
#  'Stock market today: BSE Sensex opens over 300 points down; Nifty50 below 22,900',
#  'Axis Bank',
#  'Provident Fund',
#  'Income Tax Slabs',
#  'GST',
#  'Fixed Deposit rates',
#  '',
#  'Recipes',
#  '',
#  'Lifestyle',
#  'Style',
#  'Sanya Malhotra’s vintage outfit roars heritage',
#  '5 celebs who grabbed eyeballs with distressed looks',
#  'Health & Fitness',
#  'Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!',
#  'Egg vs Paneer: Which one is a better source of protein for weight loss',
#  'Relationship',
#  'Personality Test: Your foot arch reveals if you are grounded or a free spirit',
#  "Meet King Charles III's dashing bodyguard, whom royal fans compare to James Bond",
#  'Food',
#  'How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh',
#  'How to make South Indian Appe with dosa batter for breakfast',
#  'Beauty',
#  "'Mrs.' actress Sanya Malhotra's curly hair routine revealed",
#  'Can Henna or Mehendi increase hair growth?',
#  'Parenting',
#  '10 morning habits successful kids are encouraged to follow',
#  'Baby names inspired by Shreenathji',
#  'Books',
#  "10 timeless lines from Mirza Ghalib's shayaris",
#  '8 books that help magically improve relationships and love issues',
#  'Videos',
#  'Control Your Senses, Gain Knowledge, Attain Peace: Bhagavad Gita, Chapter 4.39',
#  'Cultural Clashes in Love: How To Make Your Relationship Work',
#  'More',
#  '10 birds that are blue in colour',
#  'What happened to the 5 Pandavas and Draupadi after the Mahabharata war',
#  'Elon Musk',
#  'Creatine Benefits',
#  'Sanya Malhotra',
#  'Mahashivratri 2025',
#  'Bhagwad Gita Lessons',
#  '',
#  'NRI',
#  "'India belongs to England': UK man racially abuses Indian-origin woman on train; see video",
#  'Indian-origin man sentenced for killing 2 teens in New York crash',
#  'Now, Australia cracks down on Indian students breaking rules on work',
#  "Elon Musk's DOGE member who wanted to 'normalize Indian hate' resigns after racist posts resurface",
#  "'Saw one die, another drown': Indians deported from US recall ‘donkey’ route ordeal",
#  'Singapore: Indian-origin opposition leader found guilty of giving false testimony',
#  'Worried about your immigration status? Get advice from experts in US immigration laws',
#  'Sikh advocacy group in US working to ensure due legal process for asylum seekers from India',
#  'Sikh leader Sukhi Chahal congratulates Tulsi Gabbard on US Senate confirmation as director of national intelligence',
#  '',
#  'Tech',
#  'Garena Free Fire Max Codes',
#  'Wordle Today',
#  'NYT Strands',
#  'NYT Connections',
#  'Mini Crossword',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
label_names
# Out:
# ['US',
#  'IN',
#  '',
#  'City',
#  'mumbai',
#  'delhi',
#  'bengaluru',
#  'Hyderabad',
#  'kolkata',
#  'chennai',
#  'City',
#  'agra',
#  'agartala',
#  'ahmedabad',
#  'ajmer',
#  'amaravati',
#  'amritsar',
#  'bareilly',
#  'bhubaneswar',
#  'bhopal',
#  'chandigarh',
#  'chhatrapati sambhajinagar',
#  'coimbatore',
#  'cuttack',
#  'dehradun',
#  'erode',
#  'faridabad',
#  'ghaziabad',
#  'goa',
#  'gurgaon',
#  'guwahati',
#  'hubballi',
#  'imphal',
#  'indore',
#  'itanagar',
#  'jaipur',
#  'jammu',
#  'jamshedpur',
#  'jodhpur',
#  'kanpur',
#  'kochi',
#  'kohima',
#  'kolhapur',
#  'kozhikode',
#  'ludhiana',
#  'lucknow',
#  'madurai',
#  'mangaluru',
#  'meerut',
#  'mumbai region',
#  'mysuru',
#  'nagpur',
#  'nashik',
#  'navi mumbai',
#  'noida',
#  'patna',
#  'prayagraj',
#  'puducherry',
#  'pune',
#  'raipur',
#  'rajkot',
#  'ranchi',
#  'thane',
#  'salem',
#  'shillong',
#  'shimla',
#  'srinagar',
#  'surat',
#  'trichy',
#  'thiruvananthapuram',
#  'udaipur',
#  'vadodara',
#  'varanasi',
#  'vijayawada',
#  'visakhapatnam',
#  'photos',
#  'Web Stories',
#  'Briefs',
#  'India',
#  'World',
#  'Business',
#  'Sports',
#  'Cricket',
#  'Entertainment',
#  'Auto',
#  'Tech',
#  'Life & Style',
#  'Photos',
#  'Blogs',
#  'Abound',
#  'ePaper',
#  'TOI+',
#  'Rekha Gupta',
#  'Sahi hai',
#  'IPL Schedule',
#  'Champions Trophy Schedule',
#  'CEC Appointment',
#  'TOISA 2024',
#  'India Schools Online',
#  'A decade ago, he was dragged out — now, Vijender Gupta will run the show as Delhi House speaker',
#  "After Trump's Indian polls expose, BJP shares old clips of PM blaming Cong",
#  'Pride of India, Asia’s first vertical-lift sea bridge set to open in TN',
#  'Will work towards mission of Viksit Delhi, says CM Rekha Gupta',
#  "'Not safe in our country': Deportees from US cry for help from Panama hotel",
#  'Everest snow cover has retreated by 490ft in 1.5 months, says study',
#  'Champions Trophy: 50-over cricket’s midlife crisis, with India twist',
#  'IND vs BAN Live: Hridoy-Jaker stand frustrate India in Dubai',
#  'Tesla likely to import cars from Germany, skip China',
#  "Watch: How Rohit Sharma messed up Axar's hat-trick chance",
#  "'Dragged out of lift, assaulted': Woman attacks minor over pet dog objection",
#  'Gurgaon lawyer held for Noida boy’s death in celebratory firing',
#  'Police receive email threat to bomb Maharashtra deputy CM Shinde’s car',
#  "'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row",
#  "California judge shoots wife during argument while watching 'Breaking Bad'",
#  'Shopping: Discounts Up to 60% Off on Gadgets & Electronics',
#  'NASA leadership changes spark uncertainty over the future of the US Moon program',
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  'Love & Dating Horoscope for February 20, 2025',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles',
#  'Horoscope Tomorrow, February 21, 2025: Your zodiac insights await',
#  'Australian children bypass social media age limit restriction as landmark ban nears: Report',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City',
#  "Trump Doubles Down On 'False' Condom Claim; '$100 Million Designated By US To Buy...'",
#  "Argentina Court Slams Liam Payne's Family, Acquits Roger Nores On 'These' Grounds | WATCH",
#  'Liam Payne Case: Argentina Court Acquits Roger Nores & 2 Hotel Employees Of All Charges',
#  "Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review",
#  'Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian Americans in entertainment sector',
#  'Horoscope Today: Astrological Predictions for February 20, 2025',
#  "Today's ePaper",
#  'SUBSCRIBE',
#  '',
#  'TOI+',
#  'Exclusive Stories',
#  'If 300-ft asteroid hits earth in 2032, Mumbai and Kolkata at high risk',
#  'Trump is upending Western-led world order and India can benefit from it',
#  "Why India doesn't need ultra-pricey F-35s & what it should get instead",
#  'Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government',
#  'MS Dhoni shares his secrets for a stress-free existence',
#  'Are dating apps the new job portals? Woman uses Hinge for job search and shares viral chat screenshots',
#  "IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed",
#  "'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot",
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!',
#  'Champions Trophy: South Africa aim to shed chokers tag against Afghanistan',
#  'Are expecting mothers in India at risk of Vitamin D deficiency during winter?',
#  'Egg vs Paneer: Which one is a better source of protein for weight loss',
#  'MS Dhoni',
#  'IND vs BAN',
#  'BJP Delhi CM',
#  'Who is Rekha Gupta',
#  'Champions Trophy Points Table',
#  'IND vs PAK Head to Head',
#  'Champions Trophy Schedule 2025',
#  'Delhi Cabinet Ministers',
#  'Sanju Samson',
#  'Lamelo Ball',
#  '',
#  '',
#  'Entertainment',
#  'Bhumi recalls falling on stage in UP in front of 30,000 people',
#  'Ministry of I&B issues an advisory to OTT platforms',
#  'Arjun REACTS to people judging him for surname-looks',
#  'Bollywood Actors Who Love Painting',
#  'Celebrity MasterChef: Net worth of the contestants',
#  "Shenaz loses a brand following Ranveer's controversy",
#  'When Ranbir left Rashmika crying on sets of Animal',
#  "Aadar calls past relationships 'time pass', faces backlash",
#  'What’s happening with the OTT deal for Sky Force?',
#  "Nicole Kidman's 'Babygirl' CENSORED in India",
#  'Vicky’s climax look in Chhaava took over four hours of make-up',
#  '6 benefits of drinking Okra water with lemon every morning',
#  'Optical illusion: What you see shows how you handle stress',
#  "Zahan Kapoor says shooting with Shah Rukh Khan was 'difficult'",
#  "Exclusive: Rozlyn shares PET scan reports with Hina's name on it",
#  'Munmun shares a hilarious video dancing to Govinda’s song',
#  "MasterChef: Farah, Ranveer and Vikas praise Gaurav's Dish",
#  "Kaveri Kapur: 'I was happy when my parents got divorced'",
#  'Vishal slams outrage over Samay and Ranveer controversy',
#  'Etimes Photos',
#  "10Dia Mirza's ethnic wear",
#  "10Sonakshi-Zaheer's adorable pics",
#  "10Amyra Dastur's golden glamour",
#  "10Tamannaah's animal print outfit",
#  "10Madhuri's white Patola saree",
#  '10Sanya redefines power dressing',
#  '11B-Town divas welcome Bappa in style',
#  '10Urmila Matondkar the timeless beauty',
#  "10Ananya Panday's style file",
#  'Reviews',
#  "ChhaavaChhaava’s excellence lies in its terrific climax. You just wish the film relied and trusted its solid story more than Rahman's music, which largely feels out of place.Critic Rating3.5",
#  'Dhoom DhaamDhoom Dhaam is a fast-paced rollercoaster of action, comedy, and mystery, powered by Yami Gautam Dhar and Pratik Gandhi’s electric chemistry.Critic Rating3.5',
#  'Captain America: Brave New WorldDespite its convoluted plot and occasional pacing issues, Brave New World delivers thrilling aerial battles and hand-to-hand combats, strong performances, and enough spectacle to entertain superheroCritic Rating3.0',
#  'Aadar Jain',
#  'Skyforce',
#  'Samay Raina',
#  'Vicky Kaushal',
#  'Arjun Kapoor',
#  'Daniel Fernandes',
#  'Justin Baldoni',
#  'Vicky Kaushal',
#  'Videos',
#  "03:20Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?",
#  "03:20Apoorva Mukhija Unfollows Everyone; Is the 'IGL' Controversy Tearing Her Inner Circle Apart?",
#  '03:10Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage & Over-the-Top Acting',
#  '24:39Exclusive: Saba Azad & Saqib Saleem Address Importance Of Self-Censorship & Side Effects Of Social Media',
#  '03:12Blake Lively Accuses Justin Baldoni of On-Set Misconduct – Shocking Allegations Surface!',
#  '03:11Supreme Court Hits Ranveer For ‘Perverted’ Remarks; Passport Seized, Travel Blocked - Calls Out His ‘Dirty Mind’',
#  '03:08Heartbreaking Goodbye: Kim Sae-Ron’s Emotional Funeral Leaves K-Stars in Tears',
#  'India',
#  'Man locks ill mother at home, takes wife, kids to Maha Kumbh for holy dip',
#  'Who are the 6 cabinet ministers sworn in with Rekha Gupta in Delhi?',
#  'Rekha Gupta takes oath as Delhi CM in presence of PM Modi, top NDA leaders',
#  'Tribunals can’t overturn its own finding on Assam foreigners: SC',
#  'SC adjourns hearing on challenge to CEC, EC selection law; hearings on pre-fixed cases consume bench’s judicial schedule',
#  "'Arvind Kejriwal will have to spend most of his time in jail': BJP's Delhi minister-pick Manjinder Singh Sirsa",
#  "Trump admits to poll interference in India, BJP shares PM's clips to pin blame on Congress",
#  'UP Budget 2025 is dedicated to Sanatan culture of India: Yogi Adityanath',
#  "'Exercise caution': Centre's advisory to OTT platforms amid 'India's Got Latent' row",
#  'In pics: Meet the newly sworn-in cabinet of Delhi assembly',
#  "'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India",
#  "'Disturbing': SC on Lokpal order which entertained complaints against sitting HC judges",
#  'Ramdev blocks Bryan Johnson on X over Haridwar air quality comment on Patanjali post',
#  "‘Nahi nahi’: Delhi CM-designate Rekha Gupta on staying in 'Sheesh Mahal'",
#  'TOI Videos',
#  "03:36Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "03:36Woman Arrested For Posting Israel PM's Fake Obituary Online | Full Detail",
#  "03:06Meghan Markle's New Show Fails To Impress, Little Preview Before Release Gets Brutal Review",
#  '03:21Hungary Against Ukraine’s EU Bid; Orban Says ‘Entry Will Burden Members’ | Details',
#  '05:09‘Trump Speaks For Himself’: Senate Majority Leader Comes In Support Of Zelensky',
#  "03:56Barbie Hsu's Ex Husband Wang Xiaofei Sparks Outrage With Contrasting Actions In China",
#  '03:10Drake’s Drone Stunt Backfires! Fans Call Out ‘Fake’ Footage & Over-the-Top Acting',
#  'City',
#  '',
#  'Gurgaon lawyer held for Noida boy’s death in celebratory firing',
#  "In picking Rekha Gupta for Delhi CM's post, RSS student wing strikes again",
#  "HC seeks Uttarakhand govt's reply as UCC form asks for live-in couples’ past info",
#  'As oven deadline looms, Maharashtra neta seeks heritage tag for Irani bakeries',
#  "Youth who entered Shah Rukh Khan's bungalow 'Mannat' in 2023 caught for burglary in Gujarat",
#  "Delhi CM's oath-taking today; BJP pulls out all stops to make it a grand affair",
#  'Wife, ‘lover’ held for killing man pursuing her rape case in UP court',
#  'Uttarakhand to ban outsiders from buying agri land',
#  'Planned drama, says Muda scam case petitioner as Lokayukta gives Siddaramaiah, his wife clean chit',
#  'Arvind Kejriwal, Atishi among those to congratulate Delhi CM-designate Rekha Gupta',
#  'Sports',
#  'LiveIND vs BAN Live: Shami breaks Towhid -Jaker stand',
#  "ICC approves Imam-ul-Haq as Fakhar's replacement in Pak squad",
#  "'Thoda aur bhaiya' - Samson's cute reaction to Dhoni's IPL career",
#  'Dominant NZ crush Pakistan in Champions Trophy opener',
#  "CT Digest: India open campaign after Pakistan's sorry start",
#  "India's spin puzzle: Why Axar, Jadeja are irreplaceable in Champions Trophy plans",
#  "07:26Champions Trophy: India's predicted XI vs Bangladesh | What Rohit Sharma said in the press",
#  "04:02Mohammad Amir Exclusive: Champions Trophy hopes, India's absence & retirement talk",
#  'MS Dhoni shares his secrets for a stress-free existence',
#  "England hope 'Bazball' fires in Champions Trophy",
#  "Watch: How Rohit Sharma messed up Axar's hat-trick chance",
#  "Had doubts if I'd ever play for India again: Mohammed Shami",
#  'Jerk Fox',
#  'Josh Allen',
#  'Patrick Mahomes',
#  'Jimmy Butler',
#  'Luka Doncic',
#  'Trending',
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Police nab ATM scammer with Rs. 17.9 Lakh; find out where the money went',
#  "Teen dies after self-injecting butterfly remains; here's what happened",
#  "IITian Baba's 10th and 12th mark-sheet goes viral: Know how he academically performed",
#  '12\u200b11 mysteries on the Earth that remain unsolved\u200b',
#  'Who is Elon Musk? Why is he so much in the news suddenly',
#  'Visual Stories',
#  '10 quotes to inspire and motivate youLifestyle',
#  '10 health benefits of chewing cloves dailyLifestyle',
#  '10 things parents should never do in the morning before sending kids to schoolLifestyle',
#  '10 powerful ways to detox and reset your mindLifestyle',
#  '10 birds that eat meat and other animalsLifestyle',
#  "10 exotic animals to spot inside Kashmir's Dachigam National ParkTravel",
#  'How to make South Indian Paneer Butter Masala Dosa for breakfastFood',
#  '\u200b10 ancient animals that still existLifestyle',
#  'Astrology',
#  'The Worst Planet for a Vacation – Where Even Travel Insurance Won’t Help',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for New York City',
#  'Which Zodiac Would Have the Best Theme Park?',
#  'Beyond swipes: 5 Zodiac signs that crave deep, real-life love',
#  'Love & Dating Horoscope for February 20, 2025',
#  'Which Zodiac Would Have the Most Aesthetic Instagram Feed?',
#  'Best Husbands by Date of Birth – Because the Stars Have a Type',
#  'Horoscope Tomorrow, February 21, 2025: Your zodiac insights await',
#  '7 Things to Absolutely Avoid During Shivratri – Unless Chaos is the Goal',
#  'Daily Muhurat Update (February 20, 2025): Tithi, Festivals, Auspicious Yogas, Rahu Kaal for Los Angeles',
#  'From swipes to soulmates: 5 Zodiac signs that shine in online dating',
#  'If Planets Were Yoga Instructors, Who Would Be the Most Annoying?',
#  'Horoscope Today: Astrological Predictions for February 20, 2025',
#  '5 Zodiac Sign Men Who Bring Unmatched Luck to Their Wives',
#  'US News',
#  "'He did this while kids were dying': Elon Musk slams Zelenskyy over wartime Vogue photoshoot",
#  'Who is Leland Dudek? Pro-DOGE ‘anti-fraud expert’ takes over as SSA chief after Michelle King’s exit',
#  "'Guess they were trying to get somebody else elected: Donald Trump on $21m fund for India",
#  "California judge shoots wife during argument while watching 'Breaking Bad'",
#  "Elon Musk 'misinterprets' Social Security data; Experts say millions of dead not receiving benefits",
#  'Watch: Mississippi lieutenant governor Delbert Hosemann collapses on Senate podium while giving speech',
#  'Steve Bannon calls Elon Musk a ‘parasitic illegal immigrant’, escalates criticism and questions his influence in the US Government',
#  'Mindy Kaling’s star on Hollywood Walk of Fame being celebrated by Indian-Americans in entertainment sector',
#  'How FBI lead Kash Patel stands to make millions from Shein the Chinese company',
#  "Donald Trump wants his new Air Force One jets fast: ‘Boeing's been building this thing forever’",
#  'Business',
#  'India auto component industry revenues to expand 8-10% in 2025-26: ICRA',
#  'GenNext less focused on building companies: Uday Kotak',
#  "Automobiles on government's list for trade talks with US",
#  'Irdai forms committee to review Insurance Act',
#  'Tesla likely to import cars from Germany, skip China',
#  'Salary hikes to be flat at 9.2%: Survey',
#  'UPI users take note! Google Pay introduces convenience fee for these transactions',
#  'Why India may raise GST on cigarettes and other tobacco products',
#  'Top stocks to buy today: Stock recommendations for February 20, 2025',
#  'Stock market today: BSE Sensex opens over 300 points down; Nifty50 below 22,900',
#  'iPhone parts maker Murata eyes India base',
#  'ICAI: Disciplinary action against 241 CAs, a new record',
#  'EV policy: Companies require Rs 2,500 crore sales in 2nd year',
#  'High frequency indicators point to economic recovery: RBI',
#  'Axis Bank',
#  'Provident Fund',
#  'Income Tax Slabs',
#  'GST',
#  'Fixed Deposit rates',
#  'Recipes',
#  "10This protein-packed Indian egg dish is among world's '50 best egg dishes'",
#  'How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh',
#  '10How to make South Indian Appe with dosa batter for breakfast',
#  '1210 protein-packed comforting dishes made with chickpeas',
#  '4\u200b3 effortless ways to set restaurant-style curd\u200b',
#  '10How to make Dhaba-style Champaran Chicken Handi at home',
#  'Lifestyle',
#  'Style',
#  "Jaya Bachchan's regal Ajrakh ensemble",
#  'Sanya Malhotra’s vintage outfit roars heritage',
#  '5 celebs who grabbed eyeballs with distressed looks',
#  'Health & Fitness',
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  'Love wearing your favourite lipstick? It might lead to THESE dangerous diseases!',
#  'Egg vs Paneer: Which one is a better source of protein for weight loss',
#  'Relationship',
#  '1210 best quotes on relationships by Sudha Murty',
#  'Personality Test: Your foot arch reveals if you are grounded or a free spirit',
#  "Meet King Charles III's dashing bodyguard, whom royal fans compare to James Bond",
#  'Food',
#  "10This protein-packed Indian egg dish is among world's '50 best egg dishes'",
#  'How a simple breakfast of egg and bread helped this 24 year old girl save Rs 83 Lakh',
#  'How to make South Indian Appe with dosa batter for breakfast',
#  'Beauty',
#  '10How to use Honey for instant hair growth',
#  "'Mrs.' actress Sanya Malhotra's curly hair routine revealed",
#  'Can Henna or Mehendi increase hair growth?',
#  'Parenting',
#  '6 types of people every child will face in life and how to deal with them',
#  '10 morning habits successful kids are encouraged to follow',
#  'Baby names inspired by Shreenathji',
#  'Books',
#  '108 most important lessons to take from the Bhagwad Gita',
#  "10 timeless lines from Mirza Ghalib's shayaris",
#  '8 books that help magically improve relationships and love issues',
#  'Videos',
#  '135 natural sources of Biotin which encourage hair growth',
#  'Control Your Senses, Gain Knowledge, Attain Peace: Bhagavad Gita, Chapter 4.39',
#  'Cultural Clashes in Love: How To Make Your Relationship Work',
#  'More',
#  '11How to grow Cherry tomatoes in the balcony in under 90 days',
#  '10 birds that are blue in colour',
#  'What happened to the 5 Pandavas and Draupadi after the Mahabharata war',
#  'Elon Musk',
#  'Creatine Benefits',
#  'Sanya Malhotra',
#  'Mahashivratri 2025',
#  'Bhagwad Gita Lessons',
#  "65 designer essential bags every 'Momager' should have",
#  '1110 things parents should never do in the morning before sending kids to school',
#  "1210 timeless lines from Mirza Ghalib's shayaris",
#  '87 fruits that help a person lose extra fat near the belly',
#  '76 benefits of drinking ginger-turmeric tea in the morning',
#  '10Sanya Malhotra approved trendy blouse designs',
#  'NRI',
#  'UK Hindus protest Islamophobia panel, say tackle all hatred',
#  "'India belongs to England': UK man racially abuses Indian-origin woman on train; see video",
#  'Indian-origin man sentenced for killing 2 teens in New York crash',
#  'Now, Australia cracks down on Indian students breaking rules on work',
#  "Elon Musk's DOGE member who wanted to 'normalize Indian hate' resigns after racist posts resurface",
#  "'Saw one die, another drown': Indians deported from US recall ‘donkey’ route ordeal",
#  'Singapore: Indian-origin opposition leader found guilty of giving false testimony',
#  'Worried about your immigration status? Get advice from experts in US immigration laws',
#  'Sikh advocacy group in US working to ensure due legal process for asylum seekers from India',
#  'Sikh leader Sukhi Chahal congratulates Tulsi Gabbard on US Senate confirmation as director of national intelligence',
#  'Tech',
#  'Garena Free Fire Max Codes',
#  'Wordle Today',
#  'NYT Strands',
#  'NYT Connections',
#  'Mini Crossword',
#  'IND vs BAN',
#  'Dana White',
#  'Taylor Swift',
#  'Lamelo Ball',
#  'Joe Burrow',
#  'Anna Kane',
#  'Lebron James',
#  'Rhea Ripley',
#  'Blake Lively',
#  'Giannis Antetokounmpo',
#  'Earthquake Andaman Sea',
#  'iPhone 16e Vs iPhone 16',
#  'GTA 6 Cheat Codes',
#  'UP Budget 2025',
#  'Evander Kane',
#  'Nothing Phone 3a Camera',
#  'Stock Market Today',
#  'What is DOGE Dividend',
#  'Live Cricket Score',
#  'Toyota Innova EV',
#  'Rekha Gupta',
#  'Anand Mahindra',
#  'Apple Discontinues iPhone Models',
#  'IND vs BAN Probable XI',
#  'IND vs PAK Head to Head',
#  'Champions Trophy Live Streaming in USA',
#  'Champions Trophy Points Table',
#  'Chamopions Trophy Live Streaming in Canada',
#  'Champions Trophy Schedule',
#  'ICC Champions Trophy Live Streaming',
#  '',
#  'About us',
#  'Create Your Own Ad',
#  'Terms of Use and Grievance Redressal Policy ',
#  'Privacy policy',
#  'Advertise with us',
#  'RSS',
#  'Newsletter',
#  'Feedback',
#  'ePaper',
#  'Sitemap',
#  'Archives',
#  'Cricbuzz',
#  'Lifestyle',
#  'Newspaper Subscription',
#  'Food News',
#  'TV',
#  'Times Prime',
#  'Travel Destinations',
#  'Whats Hot',
#  'ETimes',
#  'Times Life',
#  'Times Pets',
#  'MyLifeXP',
#  'CouponDunia',
#  'TechGig',
#  'TimesJobs',
#  'Bollywood News',
#  'Times Mobile',
#  'Gadgets',
#  'Work with Us',
#  'Colombia',
#  'Shashi Kapoor',
#  'Okra Water Benefits',
#  'Cancer Symptoms',
#  'Archana Puran Singh',
#  'Optical illusion',
#  'Ginger Turmeric Tea Benefits',
#  'Kaveri Kapur',
#  'Magnesium Deficiency',
#  'Samay Raina',
#  'Ranveer Allahbadia',
#  'Nita Ambani',
#  'Kirti Kulhari',
#  'Chhaava Box Office Collection',
#  'Planet Parade 2025',
#  'Rekha Gupta',
#  'Mahashivratri 2025',
#  'Chhaava Movie Review',
#  'Nostradamus Predictions 2025',
#  'Cloves Benefits',
#  'Mind Detox Tips',
#  'Parenting Mistake',
#  'Dachigam National Park',
#  'Paneer Butter Masala Dosa Recipe',
#  'Ancient Animals',
#  'Meat Eater Birds',
#  'Oats Omelette Recipe',
#  'Indian River Fishes',
#  'Animal Species',
#  'Collagen Boosting Drink',
#  'Best Indian Egg Dish',
#  'TS EAMCET 2025',
#  'CSIR UGC NET',
#  'UPSC CMS 2025',
#  'Yastika Acharya',
#  'India vs Bangladesh',
#  'Champions Trophy Points Table',
#  'Union Bank Recruitment 2025',
#  'Belal Muhammad vs Jack Della Maddalena',
#  'UFC 314 Lineup Updates',
#  'CBSE Yearly Exam Pattern',
#  'Who is Rekha Gupta',
#  'Patricio Freire',
#  'LNMU UG Result 2025',
#  'Elon Musk',
#  'Fakhar Zaman',
#  'Nyt Connections',
#  'Nyt Strands',
#  'Government Orders ToBanApps',
#  'King Legacy Codes',
#  'Da Hood Codes',
#  'iPhone 16e Vs iPhone 16',
#  'iPhone 16e',
#  'IND vs BAN Head to Head',
#  'Jharkhand Board Exam Cancel',
#  'IND vs NZ Head to Head',
#  'IND vs PAK Head to Head',
#  'IND vs PAK Champions Trophy',
#  'Champions Trophy Live Streaming in USA',
#  'Champions Trophy Live Streaming in Canada',
#  'ICC Champions Trophy 2025 Live Streaming',
#  'Headlines',
#  'Sports News',
#  'Business News',
#  'India News',
#  'World News',
#  'Bollywood News',
#  'Health+ Tips',
#  'Indian TV Shows',
#  'Technology',
#  'ICC Champions Trophy',
#  'IPL',
#  'Travel',
#  'Etimes',
#  'Health & Fitness',
#  'Hollywood News',
#  'Web Series',
#  'WWE',
#  'US News',
#  'NFL',
#  'India vs Pakistan Head to Head',
#  'India Vs New Zealand Head to Head',
#  'India vs Bangladesh Head to Head',
#  'CBSE',
#  'Technology News',
#  'International Sports',
#  'Astrology',
#  'Public Holidays',
#  'Bank Holidays',
#  'TOISA',
#  'Medithon',
#  'Velavan Senthilkumar',
#  'Vijaya Ekadashi 2025: Date, Parana Time, Rituals and Significance',
#  "Police halt 'Suriya 45' shoot due to lack of proper filming permissions",
#  'NHL Commissioner predicts massive viewership for USA-Canada rematch',
#  'Anand Mahindra shares video on mobile phone evolution and questions its future: “Implants in our brains?”',
#  'Measles outbreak in Texas and New Mexico intensifies: Symptoms and severe complications to watch out for',
#  'Ministry of Information and Broadcasting issues an advisory to OTT platforms to regulate the alleged spread of obscene content',
#  'Sidney Crosby’s heartbreaking loss worries fans ahead of Team Canada’s final against Team USA as he grieves',
#  'Australian children bypass social media age limit restriction as landmark ban nears: Report',
#  'Best Roleplay Servers You Should Try Out in GTA Online',
#  'TikTok layoffs: Job cuts to affect employees in this unit',
#  "Jason Kelce is not the Emergency Contact of his wife, Kylie Kelce, and here's why",
#  'Cobra Kai Season 6 ends with John Kreese’s ultimate sacrifice',
#  '‘Wicked’ set to stream on OTT: Know release date, cast, and other DEETS',
#  'Sebi mulls framework for fast track follow-on offer by REITs, InvITs',
#  "Trump admits to poll interference in India, BJP shares PM's clips to pin blame on Congress",
#  "Will Smith confirms 'Hancock 2' is in development; hints at Zendaya joining the cast",
#  "Arjun Kapoor REACTS to people judging him based on his surname and looks: 'I don’t appreciate that kind of criticism...'",
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
#  'https://timesofindia.indiatimes.com/sports/esports/gta/best-roleplay-servers-you-should-try-out-in-gta-online/articleshow/118418057.cms',
#  'https://timesofindia.indiatimes.com/technology/tech-news/tiktok-layoffs-job-cuts-to-affect-employees-in-this-unit/articleshow/118418541.cms',
#  'https://timesofindia.indiatimes.com/sports/nfl/news/jason-kelce-is-not-the-emergency-contact-of-his-wife-kylie-kelce-and-heres-why/articleshow/118417999.cms',
#  'https://timesofindia.indiatimes.com/web-series/news/english/cobra-kai-season-6-ends-with-john-kreeses-ultimate-sacrifice/articleshow/118418432.cms',
#  'https://timesofindia.indiatimes.com/entertainment/english/hollywood/news/wicked-set-to-stream-on-ott-know-release-date-cast-and-other-deets/articleshow/118417431.cms',
#  'https://timesofindia.indiatimes.com/business/india-business/sebi-mulls-framework-for-fast-track-follow-on-offer-by-reits-invits/articleshow/118418314.cms',
#  'https://timesofindia.indiatimes.com/india/trump-admits-to-poll-interference-in-india-bjp-shares-pms-clips-to-pin-blame-on-congress/articleshow/118413701.cms',
#  'https://timesofindia.indiatimes.com/entertainment/english/hollywood/news/will-smith-confirms-hancock-2-is-in-development-hints-at-zendaya-joining-the-cast/articleshow/118418297.cms',
#  'https://timesofindia.indiatimes.com/entertainment/hindi/bollywood/news/arjun-kapoor-reacts-to-people-judging-him-based-on-his-surname-and-looks-i-dont-appreciate-that-kind-of-criticism-/articleshow/118417480.cms',
#  'https://www.facebook.com/TimesofIndia/',
#  'https://twitter.com/timesofindia',
#  'https://timesofindia.indiatimes.com/rss.cms',
#  'https://www.youtube.com/timesofindia',
#  'https://www.instagram.com/timesofindia/',
#  'https://www.linkedin.com/company/timesofindia/',
#  'https://en.wikipedia.org/wiki/The_Times_of_India']

# %%
img_urls
# Out:
# [None,
#  None,
#  'https://static.toiimg.com/photo/79638690.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/thumb/imgsize-36024,msid-118408115,width-600,resizemode-4/118408115.jpg',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  'https://static.toiimg.com/thumb/imgsize-839738,msid-118401499,width-600,resizemode-4,quality-80/118401499.jpg',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  'https://static.toiimg.com/photo/87458172.cms',
#  'https://static.toiimg.com/photo/87458172.cms',
#  'https://static.toiimg.com/photo/87458172.cms',
#  'https://static.toiimg.com/photo/87458172.cms',
#  'https://static.toiimg.com/photo/87458172.cms',
#  'https://static.toiimg.com/photo/87458172.cms',
#  'https://static.toiimg.com/photo/87458172.cms',
#  'https://static.toiimg.com/photo/87458172.cms',
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  'https://static.toiimg.com/photo/83033472.cms',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
#Printing and Checking Lengths

print(len(label_names))
print(len(label_link))
print(len(img_urls))
print(len(descriptions))
# Out:
# 573
# 573
# 573
# 309

# %%
  #Ensuring Consistent Lengths

min_length = min(len(label_names), len(label_link), len(img_urls), len(descriptions))

label_names = label_names[:min_length]
label_link = label_link[:min_length]
img_urls = img_urls[:min_length]
descriptions = descriptions[:min_length]

# %%
#Creating a Pandas DataFrame

df = pd.DataFrame({
    "Label Names": label_names,
    "Label Links": label_link,
    "Image URLs": img_urls,
    "Description": description  # Combined description
})

# %%
df
# Out:
#                                            Label Names  \
# 0                                                   US
# 1                                                   IN
# 2
# 3                                                 City
# 4                                               mumbai
# ..                                                 ...
# 304                                           Business
# 305  India auto component industry revenues to expa...
# 306  GenNext less focused on building companies: Ud...
# 307  Automobiles on government's list for trade tal...
# 308      Irdai forms committee to review Insurance Act
#
#                                            Label Links  \
# 0               https://timesofindia.indiatimes.com/us
# 1          https://timesofindia.indiatimes.com/?loc=in
# 2                  https://timesofindia.indiatimes.com
# 3             https://timesofindia.indiatimes.com/city
# 4      https://timesofindia.indiatimes.com/city/mumbai
# ..                                                 ...
# 304       https://timesofindia.indiatimes.com/business
# 305  https://timesofindia.indiatimes.com/business/i...
# 306  https://timesofindia.indiatimes.com/business/i...
# 307  https://timesofindia.indiatimes.com/business/i...
# 308  https://timesofindia.indiatimes.com/business/i...
#
#                                        Image URLs  \
# 0                                            None
# 1                                            None
# 2    https://static.toiimg.com/photo/79638690.cms
# 3                                            None
# 4                                            None
# ..                                            ...
# 304                                          None
# 305  https://static.toiimg.com/photo/83033472.cms
# 306                                          None
# 307                                          None
# 308                                          None
#
#                                            Description
# 0    Chhaava’s excellence lies in its terrific clim...
# 1    Dhoom Dhaam is a fast-paced rollercoaster of a...
# 2    Despite its convoluted plot and occasional pac...
# 3                10 quotes to inspire and motivate you
# 4           10 health benefits of chewing cloves daily
# ..                                                 ...
# 304
# 305
# 306
# 307
# 308
#
# [309 rows x 4 columns]

# %%
df.to_csv('TOI_info.csv',index=False)
df
# Out:
#                                            Label Names  \
# 0                                                   US
# 1                                                   IN
# 2
# 3                                                 City
# 4                                               mumbai
# ..                                                 ...
# 304                                           Business
# 305  India auto component industry revenues to expa...
# 306  GenNext less focused on building companies: Ud...
# 307  Automobiles on government's list for trade tal...
# 308      Irdai forms committee to review Insurance Act
#
#                                            Label Links  \
# 0               https://timesofindia.indiatimes.com/us
# 1          https://timesofindia.indiatimes.com/?loc=in
# 2                  https://timesofindia.indiatimes.com
# 3             https://timesofindia.indiatimes.com/city
# 4      https://timesofindia.indiatimes.com/city/mumbai
# ..                                                 ...
# 304       https://timesofindia.indiatimes.com/business
# 305  https://timesofindia.indiatimes.com/business/i...
# 306  https://timesofindia.indiatimes.com/business/i...
# 307  https://timesofindia.indiatimes.com/business/i...
# 308  https://timesofindia.indiatimes.com/business/i...
#
#                                        Image URLs  \
# 0                                            None
# 1                                            None
# 2    https://static.toiimg.com/photo/79638690.cms
# 3                                            None
# 4                                            None
# ..                                            ...
# 304                                          None
# 305  https://static.toiimg.com/photo/83033472.cms
# 306                                          None
# 307                                          None
# 308                                          None
#
#                                            Description
# 0    Chhaava’s excellence lies in its terrific clim...
# 1    Dhoom Dhaam is a fast-paced rollercoaster of a...
# 2    Despite its convoluted plot and occasional pac...
# 3                10 quotes to inspire and motivate you
# 4           10 health benefits of chewing cloves daily
# ..                                                 ...
# 304
# 305
# 306
# 307
# 308
#
# [309 rows x 4 columns]

# %%
#NULL VALUES

df.isnull().sum()
# Out:
# Label Names      0
# Label Links      0
# Image URLs     213
# Description      0
# dtype: int64
